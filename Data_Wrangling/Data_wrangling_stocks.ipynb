# %% [markdown]
# # This goal of this notebook is to create a dataset of US stocks and associated key financial ratios.
# - Steps include:
#     - Pull stock tickers from an API for the financial data compiler service Financial Modeling Prep (https://site.financialmodelingprep.com/developer/docs/)
#     - Filter to applicable US stocks
#     - Join with pricing data and calculate annual return
#     - Pull financial ratios and sector data
#     - Clean data and export to csv
#
# #
# ## Note: This notebook was created for educational purposes and to improve data wrangling skills. It should not be used in for financial decisions in any way
# #
# - Author: Will Merline

# %%
from urllib.request import urlopen
import certifi
import json

import numpy as np
import pandas as pd

# %% [markdown]
# ## Pull stock tickers

# %%
# Get stock list
stock_list = ("https://financialmodelingprep.com/api/v3/available-traded/list?apikey=4f3f56682d5bbab7a42251bad1821ade")
print(stock_list)
# Out:
# https://financialmodelingprep.com/api/v3/available-traded/list?apikey=4f3f56682d5bbab7a42251bad1821ade

# %%
# Create dataframe
df = pd.read_json(stock_list)

# %%
df
# Out:
#           symbol                                          name      price  \
# 0         ADN.AX                      Andromeda Metals Limited      0.021
# 1         RTC.DE                                   RealTech AG      1.060
# 2          FUPPF                             Fuchs Petrolub SE     41.460
# 3          ICSIX       Dynamic U.S. Opportunity Fund - Class I     15.690
# 4            BYU                          BAIYU Holdings, Inc.      1.600
# ...          ...                                           ...        ...
# 54977        ALL                      The Allstate Corporation    139.600
# 54978       MYPS                             PLAYSTUDIOS, Inc.      2.670
# 54979  600615.SS               Shanghai Fenghwa Group Co., Ltd     12.700
# 54980  102110.KS                     Mirae Asset TIGER 200 ETF  34420.000
# 54981    ASAI.ST  Artificial Solutions International AB (publ)      0.241
#
#                              exchange exchangeShortName   type
# 0      Australian Securities Exchange               ASX  stock
# 1            Frankfurt Stock Exchange             XETRA  stock
# 2                           Other OTC               PNK  stock
# 3                              NASDAQ            NASDAQ  trust
# 4                NASDAQ Global Market            NASDAQ  stock
# ...                               ...               ...    ...
# 54977         New York Stock Exchange              NYSE  stock
# 54978            NASDAQ Global Market            NASDAQ  stock
# 54979                        Shanghai               SHH  stock
# 54980                             KSE               KSC    etf
# 54981        Stockholm Stock Exchange               STO  stock
#
# [54982 rows x 6 columns]

# %%
# Check stock exchanges in dataset:
df['exchangeShortName'].unique()
# Out:
# array(['ASX', 'XETRA', 'PNK', 'NASDAQ', 'SAO', 'JPX', 'JKT', 'STO', 'LSE',
#        'SET', 'SHZ', 'TSX', 'SHH', 'NSE', 'WSE', 'ATH', 'AMEX', 'NYSE',
#        'HKSE', 'SAU', 'KSC', 'TLV', 'JNB', 'ASE', 'KOE', 'OTC',
#        'EURONEXT', 'BUE', 'HEL', 'MIL', 'VIE', 'TAI', 'NEO', 'ETF', 'TWO',
#        'IST', 'CPH', 'CNQ', 'NZE', 'OSL', 'SIX', 'BUD', 'SES', 'MEX',
#        'KLS', 'KUW', 'CBOE', 'SGO', 'BRU', 'DOH', 'BME', 'AMS', 'IOB',
#        'ICE', 'DXE', 'RIS', 'STU', 'AQS', 'BSE', 'CAI', 'PRA', 'ISE',
#        'DFM', 'HAM', None], dtype=object)

# %%
df['exchangeShortName'].value_counts()
# Out:
# NASDAQ    8566
# PNK       5730
# LSE       5110
# NYSE      3079
# JPX       2603
#           ...
# KUW          3
# AQS          2
# RIS          1
# ISE          1
# HAM          1
# Name: exchangeShortName, Length: 64, dtype: int64

# %%
# Get primary US stock exchanges: NASDAQ and New York Stock Exchange (NYSE):
US_exchanges = ['NASDAQ', 'NYSE']

# %%
print("NASDAQ values:", (df['exchangeShortName']=='NASDAQ').sum())
print("NYSE values:", (df['exchangeShortName']=='NYSE').sum())
print("Total:", (df['exchangeShortName']=='NASDAQ').sum() + (df['exchangeShortName']=='NYSE').sum())
# Out:
# NASDAQ values: 8566
# NYSE values: 3079
# Total: 11645

# %%
# Filter stock list to US exchanges:
df_US_stocks = df.loc[df['exchangeShortName'].isin(US_exchanges)]
df_US_stocks
# Out:
#         symbol                                     name     price  \
# 3        ICSIX  Dynamic U.S. Opportunity Fund - Class I   15.6900
# 4          BYU                     BAIYU Holdings, Inc.    1.6000
# 8        MBEYX          AMG GW&K Global Allocation Fund   11.7300
# 10       FAASX          Fidelity Asset Manager 70% Fund   25.7900
# 22       FFRHX       Fidelity Floating Rate High Income    9.2700
# ...        ...                                      ...       ...
# 54980      UFI                              Unifi, Inc.    6.2800
# 54985  GMRE-PA                 Global Medical REIT Inc.   25.3201
# 54986     FHLT                  Future Health ESG Corp.   10.5800
# 54989      ALL                 The Allstate Corporation  139.4550
# 54990     MYPS                        PLAYSTUDIOS, Inc.    2.6600
#
#                       exchange exchangeShortName   type
# 3                       NASDAQ            NASDAQ  trust
# 4         NASDAQ Global Market            NASDAQ  stock
# 8                       NASDAQ            NASDAQ  trust
# 10                      NASDAQ            NASDAQ  trust
# 22                      NASDAQ            NASDAQ  trust
# ...                        ...               ...    ...
# 54980  New York Stock Exchange              NYSE  stock
# 54985  New York Stock Exchange              NYSE  trust
# 54986    NASDAQ Capital Market            NASDAQ  stock
# 54989  New York Stock Exchange              NYSE  stock
# 54990     NASDAQ Global Market            NASDAQ  stock
#
# [11645 rows x 6 columns]

# %%
# Check values after filter:

print("NASDAQ values:", (df_US_stocks['exchangeShortName']=='NASDAQ').sum())
print("NYSE values:", (df_US_stocks['exchangeShortName']=='NYSE').sum())
print("Total:", (df_US_stocks['exchangeShortName']=='NASDAQ').sum() + (df_US_stocks['exchangeShortName']=='NYSE').sum())
# Out:
# NASDAQ values: 8566
# NYSE values: 3079
# Total: 11645

# %%
# Check tickers by product type:

df_US_stocks
df_US_stocks['type'].value_counts()
# Out:
# stock    6799
# trust    4254
# etf       591
# fund        1
# Name: type, dtype: int64

# %%
# Filter out trusts and etfs:
df_US_stocks2 = df_US_stocks.loc[df_US_stocks['type'] == 'stock']

# %%
# Check value  counts after removing trusts and etfs:
df_US_stocks2['type'].value_counts()
# Out:
# stock    6799
# Name: type, dtype: int64

# %%
df_US_stocks2
# Out:
#        symbol                            name    price  \
# 4         BYU            BAIYU Holdings, Inc.    1.600
# 23        BCS                    Barclays PLC    7.525
# 26       CBRE                CBRE Group, Inc.   91.540
# 50       TWLO                     Twilio Inc.   75.900
# 59        WBA  Walgreens Boots Alliance, Inc.   25.435
# ...       ...                             ...      ...
# 54979  INN-PE   Summit Hotel Properties, Inc.   19.600
# 54980     UFI                     Unifi, Inc.    6.280
# 54986    FHLT         Future Health ESG Corp.   10.580
# 54989     ALL        The Allstate Corporation  139.455
# 54990    MYPS               PLAYSTUDIOS, Inc.    2.660
#
#                       exchange exchangeShortName   type
# 4         NASDAQ Global Market            NASDAQ  stock
# 23     New York Stock Exchange              NYSE  stock
# 26     New York Stock Exchange              NYSE  stock
# 50     New York Stock Exchange              NYSE  stock
# 59        NASDAQ Global Select            NASDAQ  stock
# ...                        ...               ...    ...
# 54979  New York Stock Exchange              NYSE  stock
# 54980  New York Stock Exchange              NYSE  stock
# 54986    NASDAQ Capital Market            NASDAQ  stock
# 54989  New York Stock Exchange              NYSE  stock
# 54990     NASDAQ Global Market            NASDAQ  stock
#
# [6799 rows x 6 columns]

# %%
# Export to CSV:
df_US_stocks2.to_csv('US_Stock_List.csv')

# %%
# Get list of stock tickers:
tickers_list = df_US_stocks2['symbol'].tolist()
tickers_list
# Out:
# ['BYU',
#  'BCS',
#  'CBRE',
#  'TWLO',
#  'WBA',
#  'TWO-PC',
#  'ARVN',
#  'CSAN',
#  'NAPA',
#  'GTN',
#  'EXPE',
#  'EVH',
#  'CRGX',
#  'EBR-B',
#  'SPGC',
#  'GOCO',
#  'RELY',
#  'BHG',
#  'TLS',
#  'DUK',
#  'ANVS',
#  'LYRA',
#  'NICE',
#  'SMFG',
#  'BTE',
#  'ACTG',
#  'ABSI',
#  'SITC',
#  'PRTC',
#  'PRPH',
#  'AMWL',
#  'MDAI',
#  'KGS',
#  'TIRX',
#  'CHSN',
#  'XPO',
#  'ESCA',
#  'POAI',
#  'KDP',
#  'EVGRU',
#  'LFT-PA',
#  'CBZ',
#  'DRH-PA',
#  'BHR',
#  'MARK',
#  'GLDD',
#  'ANSCU',
#  'EFOI',
#  'WNNR-UN',
#  'BWAQ',
#  'FTFT',
#  'PSNY',
#  'AREC',
#  'WTRG',
#  'OSUR',
#  'AQN',
#  'ASBA',
#  'SB-PD',
#  'DUETU',
#  'KACL',
#  'TRIS',
#  'GRIN',
#  'MCFT',
#  'CTMX',
#  'FWRG',
#  'BIGC',
#  'HLF',
#  'AAN',
#  'VLRS',
#  'CAR',
#  'INSP',
#  'OXLCO',
#  'MRSN',
#  'PETZ',
#  'IIIV',
#  'JOE',
#  'MUFG',
#  'PTON',
#  'TRON',
#  'CRGY',
#  'TDW',
#  'AG',
#  'MBWM',
#  'FATH',
#  'RILYP',
#  'CMRE-PC',
#  'EVRG',
#  'RITM-PB',
#  'AIH',
#  'BRO',
#  'PCTTW',
#  'DBI',
#  'FA',
#  'PRIF-PJ',
#  'HQL',
#  'XGN',
#  'AITRU',
#  'BE',
#  'VMAR',
#  'WTTR',
#  'CIB',
#  'DZSI',
#  'DBRG-PH',
#  'MITT-PB',
#  'XYL',
#  'ATCO-PH',
#  'DTC',
#  'SLMBP',
#  'VMCAW',
#  'EDBL',
#  'IPW',
#  'PEGRU',
#  'TLSI',
#  'MOTS',
#  'GGROW',
#  'FORA',
#  'BBDC',
#  'VICI',
#  'WPRT',
#  'APRE',
#  'THCH',
#  'SPPL',
#  'SAM',
#  'KFFB',
#  'EVGN',
#  'MLCO',
#  'BZFDW',
#  'SCLXW',
#  'ECC-PD',
#  'GNLN',
#  'CYCN',
#  'NGL-PB',
#  'ROKU',
#  'CDNA',
#  'GEN',
#  'TTP',
#  'HON',
#  'AKTS',
#  'FPH',
#  'NGG',
#  'GBNH',
#  'NVAX',
#  'SEM',
#  'ING',
#  'SPCB',
#  'ESAB',
#  'CHAA',
#  'AGFY',
#  'INST',
#  'TSRI',
#  'DGICB',
#  'MCAF',
#  'BBDO',
#  'WILC',
#  'WEC',
#  'MGNX',
#  'HTZWW',
#  'BSX',
#  'ARES',
#  'VBNK',
#  'KLTR',
#  'ELIQ',
#  'PRSO',
#  'ARR-PC',
#  'LSDI',
#  'CTRM',
#  'VSEC',
#  'LPL',
#  'ESAC',
#  'FFIV',
#  'AUTL',
#  'RDI',
#  'BYTSW',
#  'ASIX',
#  'FATBP',
#  'LIQT',
#  'BNGO',
#  'CDMO',
#  'MRIN',
#  'SRPT',
#  'CMAX',
#  'OPTN',
#  'HD',
#  'TPC',
#  'AGR',
#  'STGW',
#  'ASPS',
#  'SKX',
#  'KRMD',
#  'AIRTP',
#  'INM',
#  'EFHTW',
#  'NXGL',
#  'AMAM',
#  'VNET',
#  'PCG',
#  'ABR-PD',
#  'SCS',
#  'NHI',
#  'SHAK',
#  'GSMGW',
#  'CHSCP',
#  'NNDM',
#  'DOOO',
#  'AMZN',
#  'MUI',
#  'CURIW',
#  'PLTR',
#  'NUVB-WT',
#  'MTDR',
#  'VERI',
#  'RNR-PG',
#  'FORTY',
#  'STAF',
#  'CHRS',
#  'ALNY',
#  'UPC',
#  'EDD',
#  'ASRV',
#  'UBS',
#  'SAH',
#  'BKCC',
#  'SONX',
#  'GPOR',
#  'FAZE',
#  'CCO',
#  'SGML',
#  'IQ',
#  'THO',
#  'FONR',
#  'POWWP',
#  'WU',
#  'QDEL',
#  'LRCX',
#  'OXBRW',
#  'BACK',
#  'NGL',
#  'TRONW',
#  'IXHL',
#  'WLFC',
#  'ACIC',
#  'TY',
#  'NVCT',
#  'PETQ',
#  'SMLP',
#  'WING',
#  'RFI',
#  'RWT',
#  'HIMS',
#  'CDR-PC',
#  'LYG',
#  'FSLY',
#  'AMPS',
#  'EBR',
#  'LTCH',
#  'ASUR',
#  'CLOER',
#  'CHMI-PA',
#  'POWW',
#  'NR',
#  'F-PB',
#  'OCC',
#  'RGA',
#  'CUZ',
#  'OTEC',
#  'BLZE',
#  'CIM-PD',
#  'NEXI',
#  'DCFC',
#  'D',
#  'PATH',
#  'ZUO',
#  'BDSX',
#  'AORT',
#  'DATS',
#  'BRD',
#  'PLCE',
#  'SLG-PI',
#  'HLTH',
#  'KNX',
#  'CMG',
#  'RNR',
#  'VXRT',
#  'APCXW',
#  'MBIN',
#  'NAMSW',
#  'MIR',
#  'SNCR',
#  'OPOF',
#  'NJR',
#  'ALPN',
#  'PIXY',
#  'OPAL',
#  'KEQU',
#  'SMR',
#  'TNP-PF',
#  'MOGO',
#  'GTLS',
#  'GAM-PB',
#  'EU',
#  'UNFI',
#  'KVYO',
#  'SCHW',
#  'DPRO',
#  'CAPT',
#  'MGRD',
#  'UZD',
#  'SPOK',
#  'VWE',
#  'BLX',
#  'PIPR',
#  'TV',
#  'SCRM',
#  'SOHON',
#  'LLYVA',
#  'CBAT',
#  'IMMX',
#  'MRAI',
#  'ATLX',
#  'INZY',
#  'CIM-PB',
#  'LAES',
#  'AGS',
#  'LNW',
#  'EC',
#  'SUPN',
#  'INTS',
#  'NEO',
#  'MWG',
#  'GF',
#  'NURO',
#  'GTHX',
#  'CNET',
#  'UVE',
#  'XERS',
#  'CTOS-WT',
#  'VISL',
#  'CCS',
#  'ENFN',
#  'XHR',
#  'AXON',
#  'CLMT',
#  'ALTR',
#  'AFGD',
#  'MICS',
#  'PGC',
#  'BARK',
#  'VOR',
#  'CLNN',
#  'HRYU',
#  'MSEX',
#  'OSI-WT',
#  'SNCE',
#  'FIACW',
#  'IAG',
#  'ITRN',
#  'TAP-A',
#  'CAMP',
#  'MNTX',
#  'KEYS',
#  'EQH',
#  'NNAGW',
#  'EE',
#  'BAOS',
#  'SBET',
#  'TSLX',
#  'ARE',
#  'HRI',
#  'FEMY',
#  'QETAR',
#  'EVA',
#  'FFIE',
#  'FNWD',
#  'CBU',
#  'VSTM',
#  'SOJE',
#  'MNTSW',
#  'SMID',
#  'CLWT',
#  'AGAE',
#  'GIFI',
#  'SOFO',
#  'WLKP',
#  'TELA',
#  'GURE',
#  'PDCO',
#  'VZ',
#  'IMOS',
#  'FENG',
#  'SPR',
#  'SXI',
#  'NLTX',
#  'AVY',
#  'FXCO',
#  'WBD',
#  'MFG',
#  'TGLS',
#  'ALC',
#  'BAERW',
#  'BTTX',
#  'KZIA',
#  'AVGR',
#  'CMI',
#  'DBD',
#  'EFX',
#  'STRR',
#  'RAIL',
#  'NEGG',
#  'DT',
#  'ZG',
#  'SNCY',
#  'OCUL',
#  'VCYT',
#  'CCCC',
#  'AIHS',
#  'DCOMP',
#  'FEBO',
#  'ARAY',
#  'VERV',
#  'GECCZ',
#  'TAL',
#  'HY',
#  'SAZ',
#  'DBGI',
#  'TTD',
#  'DAN',
#  'NCMI',
#  'AVDL',
#  'SAR',
#  'KUKE',
#  'ENG',
#  'HAE',
#  'CARR',
#  'SAVA',
#  'WVE',
#  'GAM',
#  'FGF',
#  'SLAC',
#  'JNJ',
#  'HTCR',
#  'CPBI',
#  'ABR-PF',
#  'MDV',
#  'GM',
#  'OPP',
#  'AKO-B',
#  'SOJD',
#  'WOW',
#  'BOF',
#  'KRNT',
#  'UPH',
#  'NREF-PA',
#  'BILI',
#  'BRDG',
#  'HRMY',
#  'BFI',
#  'SNPO',
#  'HTBI',
#  'FBMS',
#  'ALYA',
#  'PINS',
#  'CNNE',
#  'OAKU',
#  'OSI-UN',
#  'AQST',
#  'CSSEP',
#  'COLD',
#  'LEGN',
#  'MSGE',
#  'POET',
#  'ZIM',
#  'INTA',
#  'OFS',
#  'DFLIW',
#  'PRDO',
#  'OBLG',
#  'CVX',
#  'ABLV',
#  'GLPI',
#  'VFF',
#  'EAI',
#  'ENCP',
#  'CBUS',
#  'NMK-PB',
#  'AFARW',
#  'OPFI',
#  'DSM',
#  'QS',
#  'FGEN',
#  'BBUC',
#  'NSTS',
#  'EIGR',
#  'GRND-WT',
#  'BBVA',
#  'SUNW',
#  'ZS',
#  'NDP',
#  'HYT',
#  'RMCF',
#  'MUJ',
#  'QIPT',
#  'BCTX',
#  'IPHA',
#  'SHOT',
#  'WSBC',
#  'LGI',
#  'ARL',
#  'NCPL',
#  'KSPN',
#  'TWIN',
#  'EQS',
#  'HIFS',
#  'DJCO',
#  'AIG-PA',
#  'BKSY-WT',
#  'LKFN',
#  'ODV',
#  'QETA',
#  'MSTR',
#  'ACABW',
#  'BALL',
#  'WDH',
#  'XOM',
#  'TRKAW',
#  'VIIAW',
#  'CFB',
#  'ETNB',
#  'GPRK',
#  'GRTS',
#  'SBSW',
#  'ACHR-WT',
#  'NXGLW',
#  'IZM',
#  'ESTA',
#  'ALNT',
#  'IPDN',
#  'SPRU',
#  'BBAR',
#  'COYA',
#  'RGNX',
#  'DLTH',
#  'AEVA',
#  'BML-PG',
#  'HSTM',
#  'LAC',
#  'IMCR',
#  'NOMD',
#  'GOGO',
#  'FDX',
#  'GSBD',
#  'FR',
#  'IDAI',
#  'MINM',
#  'SEED',
#  'CRK',
#  'CLSK',
#  'APEI',
#  'XPDBU',
#  'APD',
#  'AFB',
#  'SR',
#  'CELU',
#  'MAN',
#  'FOA-WT',
#  'PTHR',
#  'GLACR',
#  'CLPR',
#  'BYFC',
#  'NOTE',
#  'GDEV',
#  'ADM',
#  'FCAP',
#  'OXUSU',
#  'AMX',
#  'SRDX',
#  'XPDB',
#  'INN',
#  'NVTS',
#  'LTHM',
#  'CLLS',
#  'UPWK',
#  'FSTR',
#  'AAL',
#  'AMBP',
#  'ENS',
#  'WALDW',
#  'FLGC',
#  'EVEX-WT',
#  'NN',
#  'X',
#  'SEEL',
#  'SVMH',
#  'PVH',
#  'COCH',
#  'KCGI-UN',
#  'BXMT',
#  'AMSWA',
#  'MXF',
#  'IMPL',
#  'NVOS',
#  'AHL-PC',
#  'SLGL',
#  'NLY',
#  'VKTX',
#  'RQI',
#  'AXTI',
#  'IMAQR',
#  'PAR',
#  'IRRX-WT',
#  'VJET',
#  'BFAC-UN',
#  'USM',
#  'EFTRW',
#  'CW',
#  'QGEN',
#  'NVNO',
#  'AWRE',
#  'PFIN',
#  'TATT',
#  'OPAD',
#  'NVIV',
#  'MOBBW',
#  'TKR',
#  'BSAC',
#  'IFIN',
#  'PTCT',
#  'MBINO',
#  'APACW',
#  'TPST',
#  'CHCI',
#  'RNR-PF',
#  'AADI',
#  'HCVI',
#  'SKGRW',
#  'IRIX',
#  'NTZ',
#  'SIRI',
#  'MREO',
#  'FIBK',
#  'SHOP',
#  'YS',
#  'FCRX',
#  'FCEL',
#  'GLBS',
#  'XMTR',
#  'VOD',
#  'RDNT',
#  'LVO',
#  'DO',
#  'BIG',
#  'PLMI',
#  'CHMI-PB',
#  'UBOH',
#  'PRSRU',
#  'GENI',
#  'BLDE',
#  'SNPS',
#  'GFAI',
#  'DALN',
#  'VEEE',
#  'MRUS',
#  'RCFA-WT',
#  'ADAP',
#  'SHCR',
#  'BRSH',
#  'ALLG',
#  'HOMB',
#  'ARWR',
#  'TH',
#  'AEY',
#  'CLNE',
#  'NUZE',
#  'EAC',
#  'PAVM',
#  'ALTG-PA',
#  'TOI',
#  'ECPG',
#  'ENTX',
#  'OMGA',
#  'BTDR',
#  'ROIC',
#  'PUK',
#  'PIRS',
#  'ISPC',
#  'CARV',
#  'BCOW',
#  'GLOG-PA',
#  'CAPTW',
#  'EMKR',
#  'GIGM',
#  'TAK',
#  'UTF',
#  'BNED',
#  'NYT',
#  'FLNC',
#  'NEPH',
#  'FMX',
#  'CWST',
#  'RELL',
#  'HQH',
#  'DFIN',
#  'HCTI',
#  'CWCO',
#  'LATGU',
#  'VLO',
#  'HUDI',
#  'MTSI',
#  'GTACU',
#  'MKC-V',
#  'ETR',
#  'ETWO',
#  'RCC',
#  'TFSL',
#  'HWM',
#  'LSAK',
#  'MFA-PC',
#  'DNUT',
#  'PRGO',
#  'TOMZ',
#  'A',
#  'BHC',
#  'EVTC',
#  'PRO',
#  'WISA',
#  'BN',
#  'GNK',
#  'DE',
#  'ANTE',
#  'CXT',
#  'SIEB',
#  'AVA',
#  'URI',
#  'MOG-A',
#  'HE',
#  'ALOT',
#  'DAL',
#  'LFMD',
#  'SBIG',
#  'GSIT',
#  'NTAP',
#  'VERBW',
#  'DD',
#  'ENTA',
#  'LL',
#  'JT',
#  'EMR',
#  'ENSC',
#  'WFC-PA',
#  'LU',
#  'GVA',
#  'MYD',
#  'C-PJ',
#  'SNT',
#  'CPRI',
#  'CTO-PA',
#  'OUST',
#  'HKD',
#  'SBFM',
#  'LGVC',
#  'CFLT',
#  'PLUR',
#  'USDP',
#  'ACHC',
#  'BOXL',
#  'DAWN',
#  'UPLD',
#  'HOUS',
#  'TXMD',
#  'PCVX',
#  'PRAX',
#  'LIVN',
#  'AUPH',
#  'MORF',
#  'CDT',
#  'TGI',
#  'SOS',
#  'BLRX',
#  'OCUP',
#  'CANO',
#  'ACET',
#  'HA',
#  'TFIN',
#  'ACAH',
#  'WSO',
#  'CAT',
#  'ERJ',
#  'NEE',
#  'ATAK',
#  'DCO',
#  'FMSTW',
#  'API',
#  'CVBF',
#  'U',
#  'MRTX',
#  'EBIX',
#  'INTG',
#  'PTGX',
#  'VRAR',
#  'TSI',
#  'PI',
#  'SUZ',
#  'CLVR',
#  'FBIO',
#  'TEVA',
#  'IVP',
#  'YTEN',
#  'CDTTW',
#  'GDEN',
#  'AMPX',
#  'BEP-PA',
#  'TXRH',
#  'FUN',
#  'TYGO',
#  'EVLO',
#  'GNFT',
#  'AVDX',
#  'CSTR',
#  'QRTEA',
#  'GLAD',
#  'BLDP',
#  'NWN',
#  'RRR',
#  'VSAT',
#  'NRG',
#  'VCEL',
#  'ELOX',
#  'BIVI',
#  'INBK',
#  'EHTH',
#  'ODP',
#  'TD',
#  'UDR',
#  'VCXB',
#  'VRNS',
#  'SCPH',
#  'HCSG',
#  'SPRO',
#  'SATL',
#  'VAXX',
#  'PFMT',
#  'IMPPP',
#  'DVAX',
#  'VOXX',
#  'NUE',
#  'ALCY',
#  'MFIC',
#  'MYSZ',
#  'QLGN',
#  'IFF',
#  'SYT',
#  'FG',
#  'RYAM',
#  'PHI',
#  'AESC',
#  'MCRI',
#  'GMBLP',
#  'NISN',
#  'CUEN',
#  'RS',
#  'KHC',
#  'RERE',
#  'QTWO',
#  'KIRK',
#  'RPID',
#  'PG',
#  'PPIH',
#  'VAL',
#  'SNN',
#  'CGA',
#  'PEGA',
#  'IAS',
#  'UNM',
#  'MUA',
#  'ELVN',
#  'TDOC',
#  'AIMD',
#  'MSS',
#  'PMTS',
#  'ABCL',
#  'SNDL',
#  'LINC',
#  'DMB',
#  'MASS',
#  'NMRD',
#  'FIVE',
#  'MDXG',
#  'ICD',
#  'GOSS',
#  'TRTN-PC',
#  'FRPT',
#  'BDTX',
#  'AHI',
#  'INDI',
#  'CODX',
#  'ATER',
#  'FAT',
#  'TETEW',
#  'RITM',
#  'APTM',
#  'SRCL',
#  'BIMI',
#  'GTACW',
#  'RAPT',
#  'AFL',
#  'SNEX',
#  'EVOK',
#  'HEPA',
#  'K',
#  'CHSCO',
#  'SWTX',
#  'ELAB',
#  'GRND',
#  'CBAY',
#  'GH',
#  'KTTA',
#  'DWSN',
#  'BREZW',
#  'BIPI',
#  'EVTV',
#  'BNIXW',
#  'BEKE',
#  'NOGN',
#  'VERU',
#  'MCK',
#  'VTVT',
#  'MVIS',
#  'LXEO',
#  'CDLX',
#  'VITL',
#  'CRBG',
#  'GDDY',
#  'SKYW',
#  'BURL',
#  'ALVO',
#  'GAN',
#  'RCUS',
#  'HUBC',
#  'VNCE',
#  'AGD',
#  'NVX',
#  'TOP',
#  'IEP',
#  'NRIX',
#  'DYN',
#  'MTRN',
#  'MESO',
#  'KVHI',
#  'WOOF',
#  'CTLT',
#  'WBX',
#  'CHEF',
#  'AMPGW',
#  'CCJ',
#  'PAGS',
#  'TBIO',
#  'CFR',
#  'RUSHB',
#  'ADBE',
#  'XELB',
#  'CRWD',
#  'CC',
#  'CIO-PA',
#  'NBSE',
#  'NOV',
#  'UIS',
#  'FTAIO',
#  'APCX',
#  'BIOL',
#  'AHL-PE',
#  'MBI',
#  'RCEL',
#  'DERM',
#  'ARGO-PA',
#  'HNST',
#  'CCM',
#  'SPKLW',
#  'BOKF',
#  'FREY-WT',
#  'CULL',
#  'KRBP',
#  'VYGR',
#  'MSA',
#  'SYRS',
#  'PRME',
#  'APACU',
#  'NGMS',
#  'MRM',
#  'CEE',
#  'FLME-UN',
#  'SFL',
#  'CREG',
#  'KURA',
#  'CFFI',
#  'ADTN',
#  'AMRN',
#  'TDS',
#  'GLOB',
#  'HFBL',
#  'PIK',
#  'ICCH',
#  ...]

# %%
# Convert tickers list to dataframe: 
df_tickers = pd.DataFrame(tickers_list, columns=['symbol'])

df_tickers
# Out:
#       symbol
# 0        BYU
# 1        BCS
# 2       CBRE
# 3       TWLO
# 4        WBA
# ...      ...
# 6794  INN-PE
# 6795     UFI
# 6796    FHLT
# 6797     ALL
# 6798    MYPS
#
# [6799 rows x 1 columns]

# %%
# Saving the Tickers dataframe to CSV file:
df_tickers.to_csv('Stock_Tickers_v1.csv')
print("Stock tickers exported to working directory")
# Out:
# Stock tickers exported to working directory

# %% [markdown]
# Note: Pricing data was downloaded into CSV files and stored locally. Pricing data was sourced from Financial Modeling Prep (https://site.financialmodelingprep.com/developer/docs/) using a free trial

# %%
# Read annual pricing csv back to dataframes:
df_2016 = pd.read_csv('Data/batch_prices_eod_2016.csv')
df_2017 = pd.read_csv('Data/batch_prices_eod_2017.csv')
df_2018 = pd.read_csv('Data/batch_prices_eod_2018.csv')
df_2019 = pd.read_csv('Data/batch_prices_eod_2019.csv')
df_2020 = pd.read_csv('Data/batch_prices_eod_2020.csv')
df_2021 = pd.read_csv('Data/batch_prices_eod_2021.csv')
df_2022 = pd.read_csv('Data/batch_prices_eod_2022.csv')

# %%
# Combine pricing dfs
df_prices = pd.concat([df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022], axis=0, ignore_index=True)
df_prices
# Out:
#          symbol        date      open       low     high    close    adjClose  \
# 0          SNDE  12/30/2016  159.5000  159.1500  159.500  159.200  159.200000
# 1          AMOT  12/30/2016   14.1587   14.1133   14.580   14.260   13.990335
# 2       8271.HK  12/30/2016    0.3100    0.3000    0.350    0.330    0.252353
# 3        BOL.PA  12/30/2016    3.3600    3.3250    3.366    3.350    3.059407
# 4       2369.TW  12/30/2016   11.7500   11.7500   11.900   11.850    9.891171
# ...         ...         ...       ...       ...      ...      ...         ...
# 348191   0I9F.L  12/30/2022  101.1500  100.1400  101.150  100.140  100.140000
# 348192   0IC7.L  12/30/2022  247.0000  245.0450  247.330  245.045  245.045000
# 348193   0IC8.L  12/30/2022  140.8100  140.8100  140.810  140.810  140.810000
# 348194   0IC9.L  12/30/2022   61.7000   60.7100   61.700   60.710   60.710000
# 348195   0ID1.L  12/30/2022  103.4700  102.1800  103.470  102.180  102.180000
#
#          volume
# 0           100
# 1         10908
# 2        564000
# 3       1051663
# 4       1003000
# ...         ...
# 348191        3
# 348192       26
# 348193      704
# 348194       10
# 348195      113
#
# [348196 rows x 8 columns]

# %%
# Inner Join df_prices with stock tickers:
df_prices2 = pd.merge(df_prices, df_tickers, how='inner', on = 'symbol')

# %%
# View dataframe:
df_prices2
# Out:
#         symbol        date      open       low    high    close   adjClose  \
# 0         RELL  12/30/2016   6.26000   6.15000   6.300   6.3000   5.098714
# 1         RELL  12/29/2017   6.56890   6.56890   6.750   6.7400   5.674603
# 2         RELL  12/31/2018   9.00000   8.44780   9.000   8.6900   7.528636
# 3         RELL  12/31/2019   5.67000   5.61000   5.740   5.6300   5.076638
# 4         RELL  12/31/2020   4.74260   4.68000   4.753   4.7100   4.485001
# ...        ...         ...       ...       ...     ...      ...        ...
# 32936     VCXB  12/30/2022  10.17000   9.77000  10.180   9.7700   9.770000
# 32937  VCXB-UN  12/30/2022  10.98500  10.45000  11.010  11.0100  11.010000
# 32938  VCXB-WT  12/30/2022   0.07525   0.07525   0.080   0.0800   0.080000
# 32939     BNRG  12/30/2022   1.48000   1.37210   1.480   1.3721   1.372000
# 32940     BOCN  12/30/2022  10.28000  10.28000  10.280  10.2800  10.280000
#
#        volume
# 0       21365
# 1        5555
# 2      140556
# 3       19503
# 4        6997
# ...       ...
# 32936   50082
# 32937    4534
# 32938    1060
# 32939     449
# 32940     138
#
# [32941 rows x 8 columns]

# %%
# Check for NAs:
df_prices2.isna().sum()/len(df_prices2)
# Out:
# symbol      0.0
# date        0.0
# open        0.0
# low         0.0
# high        0.0
# close       0.0
# adjClose    0.0
# volume      0.0
# dtype: float64

# %%
# Saving the pricing dataframe to CSV file:
df_prices2.to_csv('Prices_v1.csv')
print("Stock tickers exported to working directory")
# Out:
# Stock tickers exported to working directory

# %% [markdown]
# ## Explortatory Data Analysis

# %%
# Check unique values:
df_prices2['symbol'].value_counts()
# Out:
# RELL       7
# EDIT       7
# VTGN       7
# SLRX       7
# PALI       7
#           ..
# SCCF       1
# BCAN       1
# BBUC       1
# BBAI-WT    1
# BOCN       1
# Name: symbol, Length: 6425, dtype: int64

# %%
# Check symbols with value counts equal to 1 (only 1 year of data):

print('Count of symbols = 1:', (df_prices2['symbol'].value_counts() == 1).sum())
print('Count of symbols > 1:', (df_prices2['symbol'].value_counts() > 1).sum())
# Out:
# Count of symbols = 1: 472
# Count of symbols > 1: 5953

# %%
# Remove symbols where value count = 1:
df_prices3 = df_prices2.copy()

df_prices3 = df_prices3[df_prices3.groupby('symbol').symbol.transform('count')>1]
df_prices3
# Out:
#       symbol        date     open      low     high   close   adjClose  \
# 0       RELL  12/30/2016   6.2600   6.1500   6.3000   6.300   5.098714
# 1       RELL  12/29/2017   6.5689   6.5689   6.7500   6.740   5.674603
# 2       RELL  12/31/2018   9.0000   8.4478   9.0000   8.690   7.528636
# 3       RELL  12/31/2019   5.6700   5.6100   5.7400   5.630   5.076638
# 4       RELL  12/31/2020   4.7426   4.6800   4.7530   4.710   4.485001
# ...      ...         ...      ...      ...      ...     ...        ...
# 32471   BNIX  12/30/2022  10.1700  10.1700  10.1701  10.170  10.170000
# 32472  BNIXW  12/31/2021   0.4700   0.4700   0.4700   0.470   0.470000
# 32473  BNIXW  12/30/2022   0.0250   0.0250   0.0250   0.025   0.025000
# 32474   BODY  12/31/2021   2.3800   2.3400   2.5000   2.370   2.370000
# 32475   BODY  12/30/2022   0.5000   0.5000   0.5370   0.526   0.526000
#
#         volume
# 0        21365
# 1         5555
# 2       140556
# 3        19503
# 4         6997
# ...        ...
# 32471    26025
# 32472      500
# 32473        0
# 32474  1617034
# 32475   423005
#
# [32469 rows x 8 columns]

# %%
# Check symbols with value counts after removing counts = 1:
print('Count of symbols = 1:', (df_prices3['symbol'].value_counts() == 1).sum())
print('Count of symbols > 1:', (df_prices3['symbol'].value_counts() > 1).sum())
# Out:
# Count of symbols = 1: 0
# Count of symbols > 1: 5953

# %%
#list_test = ['AAPL', 'META', 'error']
#len(list_test)
# Out:
# 3

# %% [markdown]
# ### Apply year and annual return

# %%
# Keep important columns: symbol, date, open, high, low, close, adjClose
cols = ['symbol', 'date', 'close', 'adjClose']
df_prices3 = df_prices3[cols]
df_prices3
# Out:
#       symbol        date   close   adjClose
# 0       RELL  12/30/2016   6.300   5.098714
# 1       RELL  12/29/2017   6.740   5.674603
# 2       RELL  12/31/2018   8.690   7.528636
# 3       RELL  12/31/2019   5.630   5.076638
# 4       RELL  12/31/2020   4.710   4.485001
# ...      ...         ...     ...        ...
# 32471   BNIX  12/30/2022  10.170  10.170000
# 32472  BNIXW  12/31/2021   0.470   0.470000
# 32473  BNIXW  12/30/2022   0.025   0.025000
# 32474   BODY  12/31/2021   2.370   2.370000
# 32475   BODY  12/30/2022   0.526   0.526000
#
# [32469 rows x 4 columns]

# %%
# Last trading day of each year: YYYY-MM-DD
    # 2016: 2016-12-30
    # 2017: 2017-12-29
    # 2018: 2018-12-31
    # 2019: 2019-12-31
    # 2020: 2020-12-31
    # 2021: 2021-12-31
    # 2022: 2022-12-30

#Dates = ['2022-12-30', '2021-12-31', '2020-12-31', '2019-12-31','2018-12-31']
#Dates
# Out:
# ['2022-12-30', '2021-12-31', '2020-12-31', '2019-12-31', '2018-12-31']

# %%
# Add a year column and sort in descending order:

df_prices4 = df_prices3.copy()
df_prices4['Year'] = pd.DatetimeIndex(df_prices4['date']).year
df_prices4.sort_values(by=['symbol', 'Year'], ignore_index=True, inplace=True, ascending=False)


df_prices4
# Out:
#       symbol        date       close    adjClose  Year
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018
# ...      ...         ...         ...         ...   ...
# 32464      A  12/31/2020  118.490000  116.890472  2020
# 32465      A  12/31/2019   85.310000   83.618065  2019
# 32466      A  12/31/2018   67.460000   65.562431  2018
# 32467      A  12/29/2017   66.970000   64.488472  2017
# 32468      A  12/30/2016   45.560000   43.479897  2016
#
# [32469 rows x 5 columns]

# %%
df_prices4['PY_adjClose'] = 0
df_prices4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022            0
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021            0
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020            0
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019            0
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018            0
# ...      ...         ...         ...         ...   ...          ...
# 32464      A  12/31/2020  118.490000  116.890472  2020            0
# 32465      A  12/31/2019   85.310000   83.618065  2019            0
# 32466      A  12/31/2018   67.460000   65.562431  2018            0
# 32467      A  12/29/2017   66.970000   64.488472  2017            0
# 32468      A  12/30/2016   45.560000   43.479897  2016            0
#
# [32469 rows x 6 columns]

# %%
# Create next_row_symbol column for linking current year close with Prior year close
df_prices4['Offset_symbol'] =  0
df_prices4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022            0
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021            0
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020            0
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019            0
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018            0
# ...      ...         ...         ...         ...   ...          ...
# 32464      A  12/31/2020  118.490000  116.890472  2020            0
# 32465      A  12/31/2019   85.310000   83.618065  2019            0
# 32466      A  12/31/2018   67.460000   65.562431  2018            0
# 32467      A  12/29/2017   66.970000   64.488472  2017            0
# 32468      A  12/30/2016   45.560000   43.479897  2016            0
#
#        Offset_symbol
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 32464              0
# 32465              0
# 32466              0
# 32467              0
# 32468              0
#
# [32469 rows x 7 columns]

# %%
# Fill offset symbol column with symbol from one row below
j = 1
for i in df_prices4['Offset_symbol']:
    try:
        df_prices4['Offset_symbol'].iloc[j-1] = df_prices4['symbol'].iloc[j]
        j = j+1
    except:
        print('\n' 'Last row, no value to fill!')

df_prices4
# Out:
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\2888858565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prices4['Offset_symbol'].iloc[j-1] = df_prices4['symbol'].iloc[j]
# Last row, no value to fill!
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022            0
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021            0
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020            0
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019            0
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018            0
# ...      ...         ...         ...         ...   ...          ...
# 32464      A  12/31/2020  118.490000  116.890472  2020            0
# 32465      A  12/31/2019   85.310000   83.618065  2019            0
# 32466      A  12/31/2018   67.460000   65.562431  2018            0
# 32467      A  12/29/2017   66.970000   64.488472  2017            0
# 32468      A  12/30/2016   45.560000   43.479897  2016            0
#
#       Offset_symbol
# 0              ZYXI
# 1              ZYXI
# 2              ZYXI
# 3              ZYXI
# 4              ZYXI
# ...             ...
# 32464             A
# 32465             A
# 32466             A
# 32467             A
# 32468             0
#
# [32469 rows x 7 columns]

# %%
# fill prior year adjusted close column
    ## NA rows to be deleted
j = 0
for i in df_prices4['PY_adjClose']:
    if df_prices4['Offset_symbol'].iloc[j] == df_prices4['symbol'].iloc[j]:
        df_prices4['PY_adjClose'].iloc[j] = df_prices4['adjClose'].iloc[j+1]

    else:
        df_prices4['PY_adjClose'].iloc[j] = 0
        
    j = j+1

df_prices4
# Out:
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\1504632125.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prices4['PY_adjClose'].iloc[j] = df_prices4['adjClose'].iloc[j+1]
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 32464      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 32465      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 32466      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 32467      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 32468      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol
# 0              ZYXI
# 1              ZYXI
# 2              ZYXI
# 3              ZYXI
# 4              ZYXI
# ...             ...
# 32464             A
# 32465             A
# 32466             A
# 32467             A
# 32468             0
#
# [32469 rows x 7 columns]

# %%
# add a key/index column consisting of symbol + year
df_prices4['Key'] = df_prices4['symbol'].astype(str) + "-" + df_prices4['Year'].astype(str)
df_prices4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 32464      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 32465      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 32466      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 32467      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 32468      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key
# 0              ZYXI  ZYXI-2022
# 1              ZYXI  ZYXI-2021
# 2              ZYXI  ZYXI-2020
# 3              ZYXI  ZYXI-2019
# 4              ZYXI  ZYXI-2018
# ...             ...        ...
# 32464             A     A-2020
# 32465             A     A-2019
# 32466             A     A-2018
# 32467             A     A-2017
# 32468             0     A-2016
#
# [32469 rows x 8 columns]

# %%
# Calculate annual return: (close / PY_adjClose) - 1
    ## Adjusted close is used as it incorporates stock splits, dividends, and new offerings
    ## Adjusted close is industry standard for calculating historical returns
df_prices4['Return'] = (df_prices4['adjClose'].astype(float) / df_prices4['PY_adjClose'].astype(float)) - 1
#df_prices4 = df_prices4.drop(columns=['Return%'])
df_prices4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 32464      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 32465      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 32466      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 32467      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 32468      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return
# 0              ZYXI  ZYXI-2022  0.551722
# 1              ZYXI  ZYXI-2021 -0.259287
# 2              ZYXI  ZYXI-2020  0.710293
# 3              ZYXI  ZYXI-2019  1.676871
# 4              ZYXI  ZYXI-2018 -0.050388
# ...             ...        ...       ...
# 32464             A     A-2020  0.397909
# 32465             A     A-2019  0.275396
# 32466             A     A-2018  0.016654
# 32467             A     A-2017  0.483179
# 32468             0     A-2016       inf
#
# [32469 rows x 9 columns]

# %%
df_prices_clean = df_prices4.copy()
df_prices_clean
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 32464      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 32465      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 32466      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 32467      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 32468      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return
# 0              ZYXI  ZYXI-2022  0.551722
# 1              ZYXI  ZYXI-2021 -0.259287
# 2              ZYXI  ZYXI-2020  0.710293
# 3              ZYXI  ZYXI-2019  1.676871
# 4              ZYXI  ZYXI-2018 -0.050388
# ...             ...        ...       ...
# 32464             A     A-2020  0.397909
# 32465             A     A-2019  0.275396
# 32466             A     A-2018  0.016654
# 32467             A     A-2017  0.483179
# 32468             0     A-2016       inf
#
# [32469 rows x 9 columns]

# %%
# Export clean prices to csv
df_prices_clean.to_csv('Prices_Clean.csv')

# %%
tickers_df = df_prices_clean['symbol']
tickers_df = tickers_df.drop_duplicates()
tickers_list = tickers_df.values.tolist()
tickers_list
# Out:
# ['ZYXI',
#  'ZYME',
#  'ZXZZT',
#  'ZXYZ-A',
#  'ZWS',
#  'ZVIA',
#  'ZUO',
#  'ZUMZ',
#  'ZTST',
#  'ZTS',
#  'ZTO',
#  'ZTEK',
#  'ZS',
#  'ZNTL',
#  'ZM',
#  'ZLAB',
#  'ZKIN',
#  'ZJZZT',
#  'ZIVOW',
#  'ZIVO',
#  'ZIP',
#  'ZIONP',
#  'ZIONO',
#  'ZIONL',
#  'ZION',
#  'ZIM',
#  'ZI',
#  'ZH',
#  'ZGN',
#  'ZG',
#  'ZFOXW',
#  'ZFOX',
#  'ZEV',
#  'ZEUS',
#  'ZETA',
#  'ZEPP',
#  'ZENV',
#  'ZD',
#  'ZCMD',
#  'ZBRA',
#  'ZBH',
#  'Z',
#  'YY',
#  'YUMC',
#  'YUM',
#  'YTRA',
#  'YTEN',
#  'YSG',
#  'YS',
#  'YRD',
#  'YQ',
#  'YPF',
#  'YOU',
#  'YORW',
#  'YMM',
#  'YMAB',
#  'YJ',
#  'YI',
#  'YGMZ',
#  'YEXT',
#  'YETI',
#  'YELP',
#  'YALA',
#  'XYL',
#  'XYF',
#  'XXII',
#  'XWEL',
#  'XTLB',
#  'XRX',
#  'XRTX',
#  'XRAY',
#  'XPRO',
#  'XPOF',
#  'XPO',
#  'XPEV',
#  'XPER',
#  'XPEL',
#  'XPDBU',
#  'XP',
#  'XOSWW',
#  'XOS',
#  'XOMAP',
#  'XOMAO',
#  'XOMA',
#  'XOM',
#  'XNET',
#  'XNCR',
#  'XMTR',
#  'XLO',
#  'XIN',
#  'XHR',
#  'XGN',
#  'XFOR',
#  'XFINW',
#  'XFINU',
#  'XFIN',
#  'XERS',
#  'XENE',
#  'XELB',
#  'XELA',
#  'XEL',
#  'XCUR',
#  'XBIT',
#  'XBIO',
#  'XAIR',
#  'X',
#  'WYNN',
#  'WY',
#  'WWW',
#  'WWD',
#  'WW',
#  'WVVIP',
#  'WVVI',
#  'WVE',
#  'WULF',
#  'WU',
#  'WTW',
#  'WTTR',
#  'WTS',
#  'WTRG',
#  'WTM',
#  'WTI',
#  'WTFCP',
#  'WTFCM',
#  'WTFC',
#  'WTER',
#  'WTBA',
#  'WT',
#  'WST',
#  'WSO',
#  'WSM',
#  'WSFS',
#  'WSC',
#  'WSBF',
#  'WSBCP',
#  'WSBC',
#  'WRLD',
#  'WRK',
#  'WRBY',
#  'WRB',
#  'WRAP',
#  'WPRT',
#  'WPP',
#  'WPM',
#  'WPC',
#  'WOW',
#  'WORX',
#  'WOR',
#  'WOOF',
#  'WOLF',
#  'WNW',
#  'WNS',
#  'WNEB',
#  'WNC',
#  'WMT',
#  'WMS',
#  'WMPN',
#  'WMK',
#  'WMG',
#  'WMB',
#  'WM',
#  'WLYB',
#  'WLY',
#  'WLKP',
#  'WLK',
#  'WLFC',
#  'WLDN',
#  'WKSPW',
#  'WKSP',
#  'WKME',
#  'WKHS',
#  'WKEY',
#  'WK',
#  'WIX',
#  'WIT',
#  'WISH',
#  'WISA',
#  'WIRE',
#  'WINVW',
#  'WINVU',
#  'WINV',
#  'WINT',
#  'WING',
#  'WINA',
#  'WIMI',
#  'WILC',
#  'WHR',
#  'WHLRP',
#  'WHLRD',
#  'WHLR',
#  'WHLM',
#  'WHG',
#  'WHF',
#  'WHD',
#  'WH',
#  'WGS',
#  'WGO',
#  'WFRD',
#  'WFG',
#  'WFCF',
#  'WFC-PZ',
#  'WFC-PY',
#  'WFC-PR',
#  'WFC-PL',
#  'WFC-PD',
#  'WFC-PC',
#  'WFC-PA',
#  'WFC',
#  'WF',
#  'WEYS',
#  'WEX',
#  'WETG',
#  'WEST',
#  'WES',
#  'WERN',
#  'WEN',
#  'WELL',
#  'WEC',
#  'WEAV',
#  'WDS',
#  'WDH',
#  'WDFC',
#  'WDC',
#  'WDAY',
#  'WD',
#  'WCN',
#  'WCC-PA',
#  'WCC',
#  'WBX',
#  'WBS-PF',
#  'WBS',
#  'WBD',
#  'WBA',
#  'WB',
#  'WAVE',
#  'WAVD',
#  'WATT',
#  'WAT',
#  'WALDW',
#  'WALD',
#  'WAL-PA',
#  'WAL',
#  'WAFU',
#  'WAFDP',
#  'WAFD',
#  'WABC',
#  'WAB',
#  'W',
#  'VZIO',
#  'VZ',
#  'VYNT',
#  'VYNE',
#  'VYGR',
#  'VXRT',
#  'VWEWW',
#  'VWE',
#  'VVX',
#  'VVV',
#  'VVPR',
#  'VVOS',
#  'VVI',
#  'VUZI',
#  'VTYX',
#  'VTVT',
#  'VTSI',
#  'VTRU',
#  'VTRS',
#  'VTR',
#  'VTOL',
#  'VTNR',
#  'VTGN',
#  'VTEX',
#  'VSTO',
#  'VSTM',
#  'VSTA',
#  'VST',
#  'VSSYW',
#  'VSH',
#  'VSEC',
#  'VSCO',
#  'VSAT',
#  'VSACW',
#  'VSAC',
#  'VS',
#  'VRTX',
#  'VRTS',
#  'VRT',
#  'VRSN',
#  'VRSK',
#  'VRRM',
#  'VRPX',
#  'VRNT',
#  'VRNS',
#  'VRNA',
#  'VRMEW',
#  'VRME',
#  'VRM',
#  'VREX',
#  'VRE',
#  'VRDN',
#  'VRCA',
#  'VRAR',
#  'VRA',
#  'VPG',
#  'VOYA-PB',
#  'VOYA',
#  'VOXX',
#  'VOXR',
#  'VOR',
#  'VOD',
#  'VNT',
#  'VNOM',
#  'VNET',
#  'VNDA',
#  'VNCE',
#  'VMI',
#  'VMEO',
#  'VMD',
#  'VMC',
#  'VMAR',
#  'VLYPP',
#  'VLYPO',
#  'VLY',
#  'VLRS',
#  'VLO',
#  'VLN',
#  'VLGEA',
#  'VLD',
#  'VLCN',
#  'VKTX',
#  'VJET',
#  'VIVK',
#  'VIVE',
#  'VIV',
#  'VITL',
#  'VIST',
#  'VISL',
#  'VIRX',
#  'VIRT',
#  'VIRI',
#  'VIRC',
#  'VIR',
#  'VIPS',
#  'VIOT',
#  'VINP',
#  'VINO',
#  'VINC',
#  'VIIAW',
#  'VIIAU',
#  'VII',
#  'VIEWW',
#  'VIEW',
#  'VICR',
#  'VICI',
#  'VIAV',
#  'VIASP',
#  'VIAO',
#  'VIA',
#  'VHI',
#  'VHC',
#  'VGR',
#  'VGAS',
#  'VFF',
#  'VFC',
#  'VEV',
#  'VET',
#  'VERY',
#  'VERX',
#  'VERV',
#  'VERU',
#  'VERO',
#  'VERI',
#  'VERBW',
#  'VERB',
#  'VERA',
#  'VEON',
#  'VEL',
#  'VEEV',
#  'VEEE',
#  'VECO',
#  'VCYT',
#  'VCTR',
#  'VCSA',
#  'VCNX',
#  'VCEL',
#  'VC',
#  'VBTX',
#  'VBNK',
#  'VBIV',
#  'VAXX',
#  'VATE',
#  'VAQC',
#  'VAPO',
#  'VANI',
#  'VALU',
#  'VALN',
#  'VALE',
#  'VAL',
#  'VAC',
#  'VABK',
#  'V',
#  'UZF',
#  'UZE',
#  'UZD',
#  'UXIN',
#  'UWMC',
#  'UVV',
#  'UVSP',
#  'UVE',
#  'UTZ',
#  'UTSI',
#  'UTRS',
#  'UTMD',
#  'UTL',
#  'UTI',
#  'UTHR',
#  'UTF',
#  'USPH',
#  'USNA',
#  'USM',
#  'USLM',
#  'USIO',
#  'USFD',
#  'USEG',
#  'USDP',
#  'USCTW',
#  'USCT',
#  'USCB',
#  'USB-PR',
#  'USB-PQ',
#  'USB-PP',
#  'USB-PH',
#  'USB-PA',
#  'USB',
#  'USAU',
#  'USAP',
#  'USAC',
#  'UROY',
#  'URI',
#  'URGN',
#  'URBN',
#  'UPXI',
#  'UPWK',
#  'UPST',
#  'UPS',
#  'UPLD',
#  'UPH',
#  'UPC',
#  'UP',
#  'UONEK',
#  'UONE',
#  'UNTY',
#  'UNP',
#  'UNMA',
#  'UNM',
#  'UNIT',
#  'UNH',
#  'UNFI',
#  'UNF',
#  'UNCY',
#  'UNB',
#  'UMH-PD',
#  'UMH',
#  'UMC',
#  'UMBF',
#  'ULTA',
#  'ULH',
#  'ULCC',
#  'ULBI',
#  'UL',
#  'UKOMW',
#  'UK',
#  'UIS',
#  'UI',
#  'UHS',
#  'UHAL',
#  'UGRO',
#  'UGP',
#  'UGIC',
#  'UGI',
#  'UG',
#  'UFPT',
#  'UFPI',
#  'UFI',
#  'UFCS',
#  'UEIC',
#  'UE',
#  'UDR',
#  'UDMY',
#  'UCTT',
#  'UCL',
#  'UCBIO',
#  'UCBI',
#  'UBX',
#  'UBSI',
#  'UBS',
#  'UBOH',
#  'UBFO',
#  'UBER',
#  'UBCP',
#  'UAN',
#  'UAL',
#  'UAA',
#  'UA',
#  'U',
#  'TZOO',
#  'TYRA',
#  'TYL',
#  'TYG',
#  'TY-P',
#  'TY',
#  'TXT',
#  'TXRH',
#  'TXN',
#  'TXMD',
#  'TXG',
#  'TX',
#  'TWST',
#  'TWOU',
#  'TWOA',
#  'TWO-PC',
#  'TWO-PB',
#  'TWO-PA',
#  'TWO',
#  'TWN',
#  'TWLVW',
#  'TWLV',
#  'TWLO',
#  'TWKS',
#  'TWIN',
#  'TWI',
#  'TW',
#  'TVTX',
#  'TVE',
#  'TVC',
#  'TV',
#  'TUYA',
#  'TUSK',
#  'TURN',
#  'TUP',
#  'TU',
#  'TTWO',
#  'TTSH',
#  'TTP',
#  'TTOO',
#  'TTNP',
#  'TTMI',
#  'TTI',
#  'TTGT',
#  'TTEK',
#  'TTEC',
#  'TTE',
#  'TTD',
#  'TTC',
#  'TT',
#  'TSVT',
#  'TSRI',
#  'TSQ',
#  'TSP',
#  'TSN',
#  'TSM',
#  'TSLX',
#  'TSLA',
#  'TSI',
#  'TSHA',
#  'TSEM',
#  'TSE',
#  'TSCO',
#  'TSBK',
#  'TSAT',
#  'TS',
#  'TRVN',
#  'TRVI',
#  'TRVG',
#  'TRV',
#  'TRUP',
#  'TRUE',
#  'TRU',
#  'TRTX-PC',
#  'TRTX',
#  'TRTN-PE',
#  'TRTN-PD',
#  'TRTN-PC',
#  'TRTN-PB',
#  'TRTN-PA',
#  'TRTL',
#  'TRST',
#  'TRS',
#  'TRP',
#  'TROX',
#  'TROW',
#  'TROO',
#  'TRONW',
#  'TRON',
#  'TRNS',
#  'TRNO',
#  'TRN',
#  'TRMR',
#  'TRMK',
#  'TRMD',
#  'TRMB',
#  'TRKAW',
#  'TRKA',
#  'TRIS-UN',
#  'TRIS',
#  'TRIP',
#  'TRIN',
#  'TRIB',
#  'TRI',
#  'TRGP',
#  'TREX',
#  'TREE',
#  'TRDA',
#  'TRCA',
#  'TRC',
#  'TR',
#  'TPZ',
#  'TPX',
#  'TPVG',
#  'TPTA',
#  'TPST',
#  'TPR',
#  'TPL',
#  'TPIC',
#  'TPH',
#  'TPC',
#  'TPB',
#  'TOWN',
#  'TOVX',
#  'TOUR',
#  'TOST',
#  'TOPS',
#  'TOMZ',
#  'TOL',
#  'TOIIW',
#  'TOI',
#  'TNYA',
#  'TNXP',
#  'TNP-PF',
#  'TNP-PE',
#  'TNP',
#  'TNL',
#  'TNK',
#  'TNGX',
#  'TNET',
#  'TNDM',
#  'TNC',
#  'TMUS',
#  'TMST',
#  'TMPOW',
#  'TMPO',
#  'TMO',
#  'TMHC',
#  'TME',
#  'TMDX',
#  'TMCWW',
#  'TMCI',
#  'TMC',
#  'TM',
#  'TLYS',
#  'TLSA',
#  'TLS',
#  'TLRY',
#  'TLK',
#  'TLIS',
#  'TLGYU',
#  'TLF',
#  'TKR',
#  'TKNO',
#  'TKC',
#  'TK',
#  'TJX',
#  'TIXT',
#  'TIVC',
#  'TITN',
#  'TISI',
#  'TIRX',
#  'TIPT',
#  'TIMB',
#  'TILE',
#  'TIL',
#  'TIGR',
#  'TIGO',
#  'THWWW',
#  'THTX',
#  'THS',
#  'THRY',
#  'THRX',
#  'THRM',
#  'THR',
#  'THO',
#  'THMO',
#  'THG',
#  'THFF',
#  'THCPW',
#  'THCPU',
#  'THCP',
#  'THCH',
#  'THC',
#  'TH',
#  'TGVCW',
#  'TGVC',
#  'TGTX',
#  'TGT',
#  'TGS',
#  'TGNA',
#  'TGLS',
#  'TGI',
#  'TGH-PB',
#  'TGH-PA',
#  'TGH',
#  'TGAN',
#  'TGAAU',
#  'TG',
#  'TFX',
#  'TFSL',
#  'TFPM',
#  'TFINP',
#  'TFIN',
#  'TFII',
#  'TFFP',
#  'TFC-PR',
#  'TFC-PO',
#  'TFC-PI',
#  'TFC',
#  'TEX',
#  'TEVA',
#  'TERN',
#  'TER',
#  'TEO',
#  'TENX',
#  'TENB',
#  'TELA',
#  'TEL',
#  'TEF',
#  'TEDU',
#  'TECTP',
#  'TECK',
#  'TECH',
#  'TEAM',
#  'TDY',
#  'TDW',
#  'TDUP',
#  'TDS-PV',
#  'TDS',
#  'TDOC',
#  'TDG',
#  'TDF',
#  'TDCX',
#  'TDC',
#  'TD',
#  'TCX',
#  'TCS',
#  'TCRX',
#  'TCRT',
#  'TCPC',
#  'TCON',
#  'TCOM',
#  'TCOA-UN',
#  'TCN',
#  'TCMD',
#  'TCI',
#  'TCBX',
#  'TCBS',
#  'TCBK',
#  'TCBIO',
#  'TCBI',
#  'TCBC',
#  'TC',
#  'TBPH',
#  'TBNK',
#  'TBLT',
#  'TBLAW',
#  'TBLA',
#  'TBIO',
#  'TBI',
#  'TBCPW',
#  'TBCPU',
#  'TBC',
#  'TBBK',
#  'TBB',
#  'TAYD',
#  'TATT',
#  'TAST',
#  'TASK',
#  'TARS',
#  'TARO',
#  'TARA',
#  'TAP-A',
#  'TAP',
#  'TAOP',
#  'TANH',
#  'TALO',
#  'TALKW',
#  'TALK',
#  'TAL',
#  'TAK',
#  'TAIT',
#  'TACT',
#  'TAC',
#  'T-PC',
#  'T-PA',
#  'T',
#  'SZZL',
#  'SYY',
#  'SYTAW',
#  'SYTA',
#  'SYRS',
#  'SYPR',
#  'SYNA',
#  'SYM',
#  'SYK',
#  'SYF-PA',
#  'SYF',
#  'SYBX',
#  'SYBT',
#  'SY',
#  'SXTC',
#  'SXT',
#  'SXI',
#  'SXC',
#  'SWX',
#  'SWVL',
#  'SWTX',
#  'SWN',
#  'SWKS',
#  'SWKH',
#  'SWK',
#  'SWIM',
#  'SWI',
#  'SWBI',
#  'SWAV',
#  'SWAGW',
#  'SWAG',
#  'SVVC',
#  'SVRA',
#  'SVFD',
#  'SUZ',
#  'SURGW',
#  'SURG',
#  'SUPV',
#  'SUPN',
#  'SUP',
#  'SUNW',
#  'SUN',
#  'SUM',
#  'SUI',
#  'SU',
#  'STZ',
#  'STX',
#  'STWD',
#  'STVN',
#  'STTK',
#  'STT-PG',
#  'STT-PD',
#  'STT',
#  'STRT',
#  'STRS',
#  'STRRP',
#  'STRR',
#  'STRO',
#  'STRM',
#  'STRL',
#  'STRCW',
#  'STRC',
#  'STRA',
#  'STR',
#  'STOK',
#  'STNG',
#  'STNE',
#  'STN',
#  'STM',
#  'STLD',
#  'STLA',
#  'STKS',
#  'STKL',
#  'STKH',
#  'STIX',
#  'STIM',
#  'STGW',
#  'STG',
#  'STEW',
#  'STER',
#  'STEP',
#  'STEM',
#  'STEL',
#  'STE',
#  'STCN',
#  'STC',
#  'STBA',
#  'STAG',
#  'STAF',
#  'STAB',
#  'STAA',
#  'ST',
#  'SSYS',
#  'SSTK',
#  'SSTI',
#  'SST',
#  'SSSSL',
#  'SSSS',
#  'SSRM',
#  'SSP',
#  'SSNT',
#  'SSNC',
#  'SSL',
#  'SSKN',
#  'SSD',
#  'SSBK',
#  'SSBI',
#  'SSB',
#  'SRZNW',
#  'SRZN',
#  'SRTS',
#  'SRT',
#  'SRRK',
#  'SRPT',
#  'SRL',
#  'SRI',
#  'SRG-PA',
#  'SRG',
#  'SREA',
#  'SRE',
#  'SRDX',
#  'SRCL',
#  'SRCE',
#  'SRC-PA',
#  'SRC',
#  'SRAX',
#  'SRAD',
#  'SR-PA',
#  'SR',
#  'SQSP',
#  'SQNS',
#  'SQM',
#  'SQFTP',
#  'SQFT',
#  'SQ',
#  'SPXC',
#  'SPWR',
#  'SPWH',
#  'SPTN',
#  'SPT',
#  'SPSC',
#  'SPRY',
#  'SPRU',
#  'SPRO',
#  'SPRC',
#  'SPRB',
#  'SPR',
#  'SPOT',
#  'SPOK',
#  'SPNT-PB',
#  'SPNT',
#  'SPNS',
#  'SPLP-PA',
#  'SPLP',
#  'SPLK',
#  'SPIR',
#  'SPI',
#  'SPH',
#  'SPGI',
#  'SPG-PJ',
#  'SPG',
#  'SPFI',
#  'SPE',
#  'SPCE',
#  'SPCB',
#  'SPB',
#  'SP',
#  'SOVO',
#  'SOUNW',
#  'SOTK',
#  'SOS',
#  'SOR',
#  'SOPH',
#  'SOPA',
#  'SONY',
#  'SONX',
#  'SONO',
#  'SONN',
#  'SONM',
#  'SONDW',
#  'SOND',
#  'SON',
#  'SOLO',
#  'SOL',
#  'SOJE',
#  'SOJD',
#  'SOJC',
#  'SOI',
#  'SOHU',
#  'SOHOO',
#  'SOHON',
#  'SOHOB',
#  'SOHO',
#  'SOFO',
#  'SOFI',
#  'SOBR',
#  'SO',
#  ...]

# %% [markdown]
# ## Pull financial ratio data
# - Note: this data can be pulled from FMP ("https://financialmodelingprep.com/api/v3/key-metrics/") with the required subscription or can be manually downloaded into CSV files

# %%
## Get financial ratio data from stocks on tickers_list ##

base_ratios = ("https://financialmodelingprep.com/api/v3/key-metrics/")
end_ratios = ("?limit=5&apikey=4f3f56682d5bbab7a42251bad1821ade")       

json_list_ratios = []
for i in tickers_list:
    url_ratios = base_ratios + i + end_ratios
    #print(get_jsonparsed_data(url))
    #print(url)
    json_ratios = pd.read_json(url_ratios)
    json_list_ratios.append(json_ratios)
   

json_list_ratios

# %%
# Convert pricing JSON files into dataframe 
df_ratios = pd.concat(json_list_ratios, axis=0, ignore_index=True)
df_ratios
# Out:
#       symbol       date period  revenuePerShare  netIncomePerShare  \
# 0       REGN 2022-12-31     FY       113.659197          40.507937
# 1       REGN 2021-12-31     FY       149.365242          75.049257
# 2       REGN 2020-12-31     FY        78.969331          32.650558
# 3       REGN 2019-12-31     FY        72.009158          19.375458
# 4       REGN 2018-12-31     FY        62.194625          22.654310
# ...      ...        ...    ...              ...                ...
# 28871   BODY 2022-12-31     FY         2.251134          -0.631541
# 28872   BODY 2021-12-31     FY         2.869802          -0.750203
# 28873   BODY 2020-12-31     FY         2.836746          -0.070401
# 28874   BODY 2019-12-31     FY         2.482628           0.106085
# 28875   BODY 2018-12-31     FY         2.595989           0.000381
#
#        operatingCashFlowPerShare  freeCashFlowPerShare  cashPerShare  \
# 0                       0.000000             34.586368     72.290383
# 1                      65.811338             60.682156     52.924721
# 2                      24.331784             18.619888     33.336431
# 3                      22.252747             18.318681     29.434982
# 4                      20.343837             16.793327     26.041705
# ...                          ...                   ...           ...
# 28871                  -0.153414             -0.239573      0.260468
# 28872                  -0.707063             -0.962990      0.341803
# 28873                   0.201789              0.077184      0.186669
# 28874                   0.138020              0.059807      0.136532
# 28875                   0.208966              0.130419           NaN
#
#        bookValuePerShare  tangibleBookValuePerShare  ...  averagePayables  \
# 0             211.615313                 203.067227  ...      576600000.0
# 1             174.431227                 174.431227  ...      519750000.0
# 2             102.465613                 102.465613  ...      446800000.0
# 3             101.554029                 101.554029  ...      318150000.0
# 4              81.161260                  81.161260  ...      198191500.0
# ...                  ...                        ...  ...              ...
# 28871           0.687966                   0.254227  ...       33159500.0
# 28872           1.265936                   0.702474  ...       38680000.0
# 28873           0.003771                  -0.127955  ...       22748000.0
# 28874          -0.035618                  -0.077851  ...              NaN
# 28875                NaN                        NaN  ...              NaN
#
#        averageInventory  daysSalesOutstanding  daysPayablesOutstanding  \
# 0          1.915700e+09            159.779141               137.822353
# 1          1.933950e+09            137.093307                84.455385
# 2          1.666050e+09            176.750362               154.975891
# 3          1.283350e+09            124.037058               195.099080
# 4          9.386690e+08            122.007510               183.466943
# ...                 ...                   ...                      ...
# 28871      9.339500e+07              0.456646                20.296256
# 28872      9.904200e+07              0.511793                53.727948
# 28873      5.254100e+07              0.361373                42.361908
# 28874               NaN              0.733111                28.661105
# 28875               NaN                   NaN                      NaN
#
#        daysOfInventoryOnHand  receivablesTurnover  payablesTurnover  \
# 0                 439.782428             2.284403          2.648337
# 1                 292.194667             2.662420          4.321809
# 2                 624.662023             2.065059          2.355205
# 3                 660.518410             2.942669          1.870844
# 4                 967.952085             2.991619          1.989459
# ...                      ...                  ...               ...
# 28871              61.160291           799.306005         17.983612
# 28872             147.405085           713.179592          6.793485
# 28873              95.528800          1010.037427          8.616231
# 28874              68.946315           497.878129         12.735029
# 28875                    NaN             0.000000          0.000000
#
#        inventoryTurnover        roe  capexPerShare
# 0               0.829956   0.191423      34.586368
# 1               1.249167   0.430251      -5.129182
# 2               0.584316   0.318649      -5.711896
# 3               0.552596   0.190790      -3.934066
# 4               0.377085   0.279127      -3.550510
# ...                  ...        ...            ...
# 28871           5.967925  -0.917983      -0.086159
# 28872           2.476170  -0.592607      -0.255927
# 28873           3.820837 -18.668990      -0.124605
# 28874           5.293974  -2.978419      -0.078213
# 28875           0.000000   0.000000      -0.078548
#
# [28876 rows x 60 columns]

# %% [markdown]
# ## Alternative method: Import data from CSV files

# %%
# Import data from CSV files:
df_ratios_2016 = pd.read_csv('Data/key_metrics_2016.csv')
df_ratios_2017 = pd.read_csv('Data/key_metrics_2017.csv')
df_ratios_2018 = pd.read_csv('Data/key_metrics_2018.csv')
df_ratios_2019 = pd.read_csv('Data/key_metrics_2019.csv')
df_ratios_2020 = pd.read_csv('Data/key_metrics_2020.csv')
df_ratios_2021 = pd.read_csv('Data/key_metrics_2021.csv')
df_ratios_2022 = pd.read_csv('Data/key_metrics_2022.csv')

# %%
# Combine into one dataframe:
df_ratios_all = pd.concat([df_ratios_2016, df_ratios_2017, df_ratios_2018, df_ratios_2019, df_ratios_2020, df_ratios_2021, df_ratios_2022])
df_ratios_all
# Out:
#           symbol        date period  revenuePerShare  netIncomePerShare  \
# 0          COD.L  12/31/2016     FY        70.485554           2.363762
# 1      600266.SS  12/31/2016     FY         5.146226           0.638889
# 2          BFLBY  12/31/2016     FY        19.222695           1.224324
# 3         LOAD.L  12/31/2016     FY         0.990908          -0.262370
# 4         FON.WA  12/31/2016     FY         0.390117          -0.526283
# ...          ...         ...    ...              ...                ...
# 20168       IRIX    1/1/2022     FY         3.495428          -0.338824
# 20169       USFD    1/1/2022     FY       132.905440           0.739190
# 20170        HNI    1/1/2022     FY        50.287951           1.376997
# 20171       HLIO    1/1/2022     FY        26.906420           3.237865
# 20172        JBI    1/1/2022     FY         1.605826           0.070155
#
#        operatingCashFlowPerShare  freeCashFlowPerShare  cashPerShare  \
# 0                       3.542939              0.800542      6.739698
# 1                      -0.771420             -0.775001      4.305225
# 2                      -1.573161             -1.888517      4.857479
# 3                       0.032453              0.025662      0.154306
# 4                      -0.014098             -0.045865      4.245777
# ...                          ...                   ...           ...
# 20168                   0.532845              0.519032      1.546722
# 20169                   1.888540              0.653552      0.667074
# 20170                   3.030342              1.498319      1.235370
# 20171                   3.504272              2.597480      0.883482
# 20172                   0.510562              0.375015      0.090010
#
#        bookValuePerShare  tangibleBookValuePerShare  ...  averagePayables  \
# 0              33.833715                  10.452121  ...     6.354000e+09
# 1               8.703012                   9.318897  ...     7.922242e+09
# 2               7.461768                   3.493349  ...     3.637000e+08
# 3               1.740733                   1.153587  ...     3.449500e+06
# 4              11.723849                  11.723849  ...     7.357689e+03
# ...                  ...                        ...  ...              ...
# 20168           1.510862                   1.305298  ...     2.772000e+06
# 20169          19.241473                  -9.852860  ...     1.662000e+09
# 20170          13.574382                   2.727220  ...     2.337590e+08
# 20171          21.946601                  -5.068474  ...     8.530100e+07
# 20172           1.830536                  -3.677706  ...     5.496100e+07
#
#        averageInventory  daysSalesOutstanding  daysPayablesOutstanding  \
# 0          6.236500e+09              0.000000                72.796846
# 1          6.882082e+10              0.000000               292.576903
# 2          4.245000e+07              0.000000                36.960347
# 3          4.028500e+06              0.000000                82.774517
# 4                   NaN              0.000000                44.628821
# ...                 ...                   ...                      ...
# 20168      7.614000e+06             65.791143                32.562436
# 20169      1.686000e+09             19.978635                24.429365
# 20170      1.815910e+08             39.624846                59.789184
# 20171      1.656290e+08             57.666544                55.959713
# 20172      5.659600e+07            166.519144               126.393298
#
#        daysOfInventoryOnHand  receivablesTurnover  payablesTurnover  \
# 0                  73.674672                  NaN          5.013953
# 1                2300.007240                  NaN          1.247535
# 2                   3.940416                  NaN          9.875448
# 3                  87.557156                  NaN          4.409570
# 4                1439.279476                  NaN          8.178571
# ...                      ...                  ...               ...
# 20168              89.440976             5.547859         11.209235
# 20169              24.782136            18.269517         14.941035
# 20170              46.446031             9.211392          6.104783
# 20171             108.657006             6.329493          6.522550
# 20172             130.153292             2.191940          2.887811
#
#        inventoryTurnover       roe  capexPerShare
# 0               4.954213  0.069864      -2.742397
# 1               0.158695  0.073410      -0.003581
# 2              92.629808  0.164080      -0.315356
# 3               4.168706 -0.150724      -0.006790
# 4               0.253599 -0.044890      -0.031766
# ...                  ...       ...            ...
# 20168           4.080904 -0.224259      -0.013812
# 20169          14.728351  0.038416      -1.234988
# 20170           7.858583  0.101441      -1.532023
# 20171           3.359194  0.147534      -0.906792
# 20172           2.804385  0.038325      -0.135547
#
# [203643 rows x 59 columns]

# %%
# Export clean prices to csv
df_ratios_all.to_csv('Ratios_All_v2.csv')

# %%
# Keep important financial columns:
cols_ratios = ['symbol', 'date', 'period', 'revenuePerShare', 'netIncomePerShare', 'operatingCashFlowPerShare', 'marketCap',
        'peRatio', 'interestCoverage', 'dividendYield']          
df_ratios2 = df_ratios_all[cols_ratios]
df_ratios2
# Out:
#           symbol        date period  revenuePerShare  netIncomePerShare  \
# 0          COD.L  12/31/2016     FY        70.485554           2.363762
# 1      600266.SS  12/31/2016     FY         5.146226           0.638889
# 2          BFLBY  12/31/2016     FY        19.222695           1.224324
# 3         LOAD.L  12/31/2016     FY         0.990908          -0.262370
# 4         FON.WA  12/31/2016     FY         0.390117          -0.526283
# ...          ...         ...    ...              ...                ...
# 20168       IRIX    1/1/2022     FY         3.495428          -0.338824
# 20169       USFD    1/1/2022     FY       132.905440           0.739190
# 20170        HNI    1/1/2022     FY        50.287951           1.376997
# 20171       HLIO    1/1/2022     FY        26.906420           3.237865
# 20172        JBI    1/1/2022     FY         1.605826           0.070155
#
#        operatingCashFlowPerShare     marketCap     peRatio  interestCoverage  \
# 0                       3.542939  2.539902e+10   19.373774          3.477064
# 1                      -0.771420  2.075904e+10   14.380435         11.610393
# 2                      -1.573161  1.418396e+09    5.241670         -1.951977
# 3                       0.032453  3.324590e+07   -5.278802         -9.047882
# 4                      -0.014098  2.422499e+07  -36.178257         49.500000
# ...                          ...           ...         ...               ...
# 20168                   0.532845  8.142288e+07  -15.583327               NaN
# 20169                   1.888540  7.822943e+09   47.700869          1.990610
# 20170                   3.030342  1.821790e+09   30.457579         12.822452
# 20171                   3.504272  2.475455e+09   23.666827          8.850039
# 20172                   0.510562  1.553557e+09  151.094844         -9.613984
#
#        dividendYield
# 0           0.026773
# 1           0.094187
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 20168            NaN
# 20169       0.003579
# 20170       0.029504
# 20171       0.004690
# 20172       0.002687
#
# [203643 rows x 10 columns]

# %%
# Add year column:
df_ratios3 = df_ratios2.copy()
df_ratios3['Year'] = pd.DatetimeIndex(df_ratios3['date']).year

df_ratios3
# Out:
#           symbol        date period  revenuePerShare  netIncomePerShare  \
# 0          COD.L  12/31/2016     FY        70.485554           2.363762
# 1      600266.SS  12/31/2016     FY         5.146226           0.638889
# 2          BFLBY  12/31/2016     FY        19.222695           1.224324
# 3         LOAD.L  12/31/2016     FY         0.990908          -0.262370
# 4         FON.WA  12/31/2016     FY         0.390117          -0.526283
# ...          ...         ...    ...              ...                ...
# 20168       IRIX    1/1/2022     FY         3.495428          -0.338824
# 20169       USFD    1/1/2022     FY       132.905440           0.739190
# 20170        HNI    1/1/2022     FY        50.287951           1.376997
# 20171       HLIO    1/1/2022     FY        26.906420           3.237865
# 20172        JBI    1/1/2022     FY         1.605826           0.070155
#
#        operatingCashFlowPerShare     marketCap     peRatio  interestCoverage  \
# 0                       3.542939  2.539902e+10   19.373774          3.477064
# 1                      -0.771420  2.075904e+10   14.380435         11.610393
# 2                      -1.573161  1.418396e+09    5.241670         -1.951977
# 3                       0.032453  3.324590e+07   -5.278802         -9.047882
# 4                      -0.014098  2.422499e+07  -36.178257         49.500000
# ...                          ...           ...         ...               ...
# 20168                   0.532845  8.142288e+07  -15.583327               NaN
# 20169                   1.888540  7.822943e+09   47.700869          1.990610
# 20170                   3.030342  1.821790e+09   30.457579         12.822452
# 20171                   3.504272  2.475455e+09   23.666827          8.850039
# 20172                   0.510562  1.553557e+09  151.094844         -9.613984
#
#        dividendYield  Year
# 0           0.026773  2016
# 1           0.094187  2016
# 2                NaN  2016
# 3                NaN  2016
# 4                NaN  2016
# ...              ...   ...
# 20168            NaN  2022
# 20169       0.003579  2022
# 20170       0.029504  2022
# 20171       0.004690  2022
# 20172       0.002687  2022
#
# [203643 rows x 11 columns]

# %%
# add a key/index column consisting of symbol + year
df_ratios3['Key'] = df_ratios3['symbol'].astype(str) + "-" + df_ratios3['Year'].astype(str)
df_ratios3
# Out:
#           symbol        date period  revenuePerShare  netIncomePerShare  \
# 0          COD.L  12/31/2016     FY        70.485554           2.363762
# 1      600266.SS  12/31/2016     FY         5.146226           0.638889
# 2          BFLBY  12/31/2016     FY        19.222695           1.224324
# 3         LOAD.L  12/31/2016     FY         0.990908          -0.262370
# 4         FON.WA  12/31/2016     FY         0.390117          -0.526283
# ...          ...         ...    ...              ...                ...
# 20168       IRIX    1/1/2022     FY         3.495428          -0.338824
# 20169       USFD    1/1/2022     FY       132.905440           0.739190
# 20170        HNI    1/1/2022     FY        50.287951           1.376997
# 20171       HLIO    1/1/2022     FY        26.906420           3.237865
# 20172        JBI    1/1/2022     FY         1.605826           0.070155
#
#        operatingCashFlowPerShare     marketCap     peRatio  interestCoverage  \
# 0                       3.542939  2.539902e+10   19.373774          3.477064
# 1                      -0.771420  2.075904e+10   14.380435         11.610393
# 2                      -1.573161  1.418396e+09    5.241670         -1.951977
# 3                       0.032453  3.324590e+07   -5.278802         -9.047882
# 4                      -0.014098  2.422499e+07  -36.178257         49.500000
# ...                          ...           ...         ...               ...
# 20168                   0.532845  8.142288e+07  -15.583327               NaN
# 20169                   1.888540  7.822943e+09   47.700869          1.990610
# 20170                   3.030342  1.821790e+09   30.457579         12.822452
# 20171                   3.504272  2.475455e+09   23.666827          8.850039
# 20172                   0.510562  1.553557e+09  151.094844         -9.613984
#
#        dividendYield  Year             Key
# 0           0.026773  2016      COD.L-2016
# 1           0.094187  2016  600266.SS-2016
# 2                NaN  2016      BFLBY-2016
# 3                NaN  2016     LOAD.L-2016
# 4                NaN  2016     FON.WA-2016
# ...              ...   ...             ...
# 20168            NaN  2022       IRIX-2022
# 20169       0.003579  2022       USFD-2022
# 20170       0.029504  2022        HNI-2022
# 20171       0.004690  2022       HLIO-2022
# 20172       0.002687  2022        JBI-2022
#
# [203643 rows x 12 columns]

# %%
cols_keep = ['period', 'revenuePerShare', 'netIncomePerShare', 'operatingCashFlowPerShare', 'marketCap',
        'peRatio', 'interestCoverage', 'dividendYield', 'Key']
df_ratios4 = df_ratios3.copy()
df_ratios4 = df_ratios4[cols_keep]
df_ratios4
# Out:
#       period  revenuePerShare  netIncomePerShare  operatingCashFlowPerShare  \
# 0         FY        70.485554           2.363762                   3.542939
# 1         FY         5.146226           0.638889                  -0.771420
# 2         FY        19.222695           1.224324                  -1.573161
# 3         FY         0.990908          -0.262370                   0.032453
# 4         FY         0.390117          -0.526283                  -0.014098
# ...      ...              ...                ...                        ...
# 20168     FY         3.495428          -0.338824                   0.532845
# 20169     FY       132.905440           0.739190                   1.888540
# 20170     FY        50.287951           1.376997                   3.030342
# 20171     FY        26.906420           3.237865                   3.504272
# 20172     FY         1.605826           0.070155                   0.510562
#
#           marketCap     peRatio  interestCoverage  dividendYield  \
# 0      2.539902e+10   19.373774          3.477064       0.026773
# 1      2.075904e+10   14.380435         11.610393       0.094187
# 2      1.418396e+09    5.241670         -1.951977            NaN
# 3      3.324590e+07   -5.278802         -9.047882            NaN
# 4      2.422499e+07  -36.178257         49.500000            NaN
# ...             ...         ...               ...            ...
# 20168  8.142288e+07  -15.583327               NaN            NaN
# 20169  7.822943e+09   47.700869          1.990610       0.003579
# 20170  1.821790e+09   30.457579         12.822452       0.029504
# 20171  2.475455e+09   23.666827          8.850039       0.004690
# 20172  1.553557e+09  151.094844         -9.613984       0.002687
#
#                   Key
# 0          COD.L-2016
# 1      600266.SS-2016
# 2          BFLBY-2016
# 3         LOAD.L-2016
# 4         FON.WA-2016
# ...               ...
# 20168       IRIX-2022
# 20169       USFD-2022
# 20170        HNI-2022
# 20171       HLIO-2022
# 20172        JBI-2022
#
# [203643 rows x 9 columns]

# %% [markdown]
# ## Join stock pricing data with financial ratios data

# %%
# Join prices with financial ratios dataframe
data = pd.merge(df_prices_clean, df_ratios4, how='inner', on = 'Key')
data
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 30008      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 30009      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 30010      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 30011      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 30012      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period  revenuePerShare  \
# 0              ZYXI  ZYXI-2022  0.551722     FY         4.111758
# 1              ZYXI  ZYXI-2021 -0.259287     FY         3.400606
# 2              ZYXI  ZYXI-2020  0.710293     FY         2.150586
# 3              ZYXI  ZYXI-2019  1.676871     FY         1.274336
# 4              ZYXI  ZYXI-2018 -0.050388     FY         0.892701
# ...             ...        ...       ...    ...              ...
# 30008             A     A-2020  0.397909     FY        17.278317
# 30009             A     A-2019  0.275396     FY        16.034161
# 30010             A     A-2018  0.016654     FY        15.073620
# 30011             A     A-2017  0.483179     FY        13.429429
# 30012             0     A-2016       inf     FY        12.618619
#
#        netIncomePerShare  operatingCashFlowPerShare     marketCap    peRatio  \
# 0               0.443185                   0.357345  5.454621e+08  31.995663
# 1               0.446355                   0.181356  2.831626e+08  16.556313
# 2               0.243559                   0.021956  6.120128e+08  67.446863
# 3               0.266010                   0.176639  3.156315e+08  33.252370
# 4               0.267164                   0.263137  1.251366e+08  13.100560
# ...                  ...                        ...           ...        ...
# 30008           2.326861                   2.980583  3.612210e+10  50.239361
# 30009           3.326087                   3.170807  2.600794e+10  24.283790
# 30010           0.969325                   3.334356  2.358610e+10  74.639555
# 30011           2.054054                   2.669670  2.305692e+10  33.708946
# 30012           1.387387                   2.381381  1.464534e+10  31.699870
#
#        interestCoverage  dividendYield
# 0             52.131818       0.006624
# 1            235.431579       0.000004
# 2            539.421053            NaN
# 3           2213.200000       0.007167
# 4             67.337662            NaN
# ...                 ...            ...
# 30008         10.846154       0.006146
# 30009         12.716216       0.007921
# 30010         12.373333       0.008098
# 30011         10.645570       0.007373
# 30012          8.541667       0.010242
#
# [30013 rows x 17 columns]

# %%
# Create prior year financial ratios columns:
data2 = data.copy()
data2[['PY_revenuePerShare', 'PY_netIncomePerShare',	'PY_operatingCashFlowPerShare',	'PY_marketCap',
      	'PY_peRatio',	'PY_interestCoverage',	'PY_dividendYield']] = 0 

data2
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 30008      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 30009      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 30010      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 30011      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 30012      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period  ...    peRatio  \
# 0              ZYXI  ZYXI-2022  0.551722     FY  ...  31.995663
# 1              ZYXI  ZYXI-2021 -0.259287     FY  ...  16.556313
# 2              ZYXI  ZYXI-2020  0.710293     FY  ...  67.446863
# 3              ZYXI  ZYXI-2019  1.676871     FY  ...  33.252370
# 4              ZYXI  ZYXI-2018 -0.050388     FY  ...  13.100560
# ...             ...        ...       ...    ...  ...        ...
# 30008             A     A-2020  0.397909     FY  ...  50.239361
# 30009             A     A-2019  0.275396     FY  ...  24.283790
# 30010             A     A-2018  0.016654     FY  ...  74.639555
# 30011             A     A-2017  0.483179     FY  ...  33.708946
# 30012             0     A-2016       inf     FY  ...  31.699870
#
#        interestCoverage  dividendYield  PY_revenuePerShare  \
# 0             52.131818       0.006624                   0
# 1            235.431579       0.000004                   0
# 2            539.421053            NaN                   0
# 3           2213.200000       0.007167                   0
# 4             67.337662            NaN                   0
# ...                 ...            ...                 ...
# 30008         10.846154       0.006146                   0
# 30009         12.716216       0.007921                   0
# 30010         12.373333       0.008098                   0
# 30011         10.645570       0.007373                   0
# 30012          8.541667       0.010242                   0
#
#        PY_netIncomePerShare  PY_operatingCashFlowPerShare  PY_marketCap  \
# 0                         0                             0             0
# 1                         0                             0             0
# 2                         0                             0             0
# 3                         0                             0             0
# 4                         0                             0             0
# ...                     ...                           ...           ...
# 30008                     0                             0             0
# 30009                     0                             0             0
# 30010                     0                             0             0
# 30011                     0                             0             0
# 30012                     0                             0             0
#
#        PY_peRatio  PY_interestCoverage  PY_dividendYield
# 0               0                    0                 0
# 1               0                    0                 0
# 2               0                    0                 0
# 3               0                    0                 0
# 4               0                    0                 0
# ...           ...                  ...               ...
# 30008           0                    0                 0
# 30009           0                    0                 0
# 30010           0                    0                 0
# 30011           0                    0                 0
# 30012           0                    0                 0
#
# [30013 rows x 24 columns]

# %%
# Reset offset_symbol column to properly index prior year financial ratios
data2['Offset_symbol'] = 0
data2
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 30008      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 30009      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 30010      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 30011      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 30012      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#        Offset_symbol        Key    Return period  ...    peRatio  \
# 0                  0  ZYXI-2022  0.551722     FY  ...  31.995663
# 1                  0  ZYXI-2021 -0.259287     FY  ...  16.556313
# 2                  0  ZYXI-2020  0.710293     FY  ...  67.446863
# 3                  0  ZYXI-2019  1.676871     FY  ...  33.252370
# 4                  0  ZYXI-2018 -0.050388     FY  ...  13.100560
# ...              ...        ...       ...    ...  ...        ...
# 30008              0     A-2020  0.397909     FY  ...  50.239361
# 30009              0     A-2019  0.275396     FY  ...  24.283790
# 30010              0     A-2018  0.016654     FY  ...  74.639555
# 30011              0     A-2017  0.483179     FY  ...  33.708946
# 30012              0     A-2016       inf     FY  ...  31.699870
#
#        interestCoverage  dividendYield  PY_revenuePerShare  \
# 0             52.131818       0.006624                   0
# 1            235.431579       0.000004                   0
# 2            539.421053            NaN                   0
# 3           2213.200000       0.007167                   0
# 4             67.337662            NaN                   0
# ...                 ...            ...                 ...
# 30008         10.846154       0.006146                   0
# 30009         12.716216       0.007921                   0
# 30010         12.373333       0.008098                   0
# 30011         10.645570       0.007373                   0
# 30012          8.541667       0.010242                   0
#
#        PY_netIncomePerShare  PY_operatingCashFlowPerShare  PY_marketCap  \
# 0                         0                             0             0
# 1                         0                             0             0
# 2                         0                             0             0
# 3                         0                             0             0
# 4                         0                             0             0
# ...                     ...                           ...           ...
# 30008                     0                             0             0
# 30009                     0                             0             0
# 30010                     0                             0             0
# 30011                     0                             0             0
# 30012                     0                             0             0
#
#        PY_peRatio  PY_interestCoverage  PY_dividendYield
# 0               0                    0                 0
# 1               0                    0                 0
# 2               0                    0                 0
# 3               0                    0                 0
# 4               0                    0                 0
# ...           ...                  ...               ...
# 30008           0                    0                 0
# 30009           0                    0                 0
# 30010           0                    0                 0
# 30011           0                    0                 0
# 30012           0                    0                 0
#
# [30013 rows x 24 columns]

# %%
j = 1
for i in data2['Offset_symbol']:
    try:
        data2['Offset_symbol'].iloc[j-1] = data2['symbol'].iloc[j]
        j = j+1
    except:
        print('\n' 'Last row, no value to fill!')

data2
# Out:
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\2579680125.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Offset_symbol'].iloc[j-1] = data2['symbol'].iloc[j]
# Last row, no value to fill!
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 30008      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 30009      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 30010      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 30011      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 30012      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period  ...    peRatio  \
# 0              ZYXI  ZYXI-2022  0.551722     FY  ...  31.995663
# 1              ZYXI  ZYXI-2021 -0.259287     FY  ...  16.556313
# 2              ZYXI  ZYXI-2020  0.710293     FY  ...  67.446863
# 3              ZYXI  ZYXI-2019  1.676871     FY  ...  33.252370
# 4              ZYXI  ZYXI-2018 -0.050388     FY  ...  13.100560
# ...             ...        ...       ...    ...  ...        ...
# 30008             A     A-2020  0.397909     FY  ...  50.239361
# 30009             A     A-2019  0.275396     FY  ...  24.283790
# 30010             A     A-2018  0.016654     FY  ...  74.639555
# 30011             A     A-2017  0.483179     FY  ...  33.708946
# 30012             0     A-2016       inf     FY  ...  31.699870
#
#        interestCoverage  dividendYield  PY_revenuePerShare  \
# 0             52.131818       0.006624                   0
# 1            235.431579       0.000004                   0
# 2            539.421053            NaN                   0
# 3           2213.200000       0.007167                   0
# 4             67.337662            NaN                   0
# ...                 ...            ...                 ...
# 30008         10.846154       0.006146                   0
# 30009         12.716216       0.007921                   0
# 30010         12.373333       0.008098                   0
# 30011         10.645570       0.007373                   0
# 30012          8.541667       0.010242                   0
#
#        PY_netIncomePerShare  PY_operatingCashFlowPerShare  PY_marketCap  \
# 0                         0                             0             0
# 1                         0                             0             0
# 2                         0                             0             0
# 3                         0                             0             0
# 4                         0                             0             0
# ...                     ...                           ...           ...
# 30008                     0                             0             0
# 30009                     0                             0             0
# 30010                     0                             0             0
# 30011                     0                             0             0
# 30012                     0                             0             0
#
#        PY_peRatio  PY_interestCoverage  PY_dividendYield
# 0               0                    0                 0
# 1               0                    0                 0
# 2               0                    0                 0
# 3               0                    0                 0
# 4               0                    0                 0
# ...           ...                  ...               ...
# 30008           0                    0                 0
# 30009           0                    0                 0
# 30010           0                    0                 0
# 30011           0                    0                 0
# 30012           0                    0                 0
#
# [30013 rows x 24 columns]

# %%
# fill prior year financial ratios columns
    ## NA rows to be deleted
j = 0
for i in data2['PY_revenuePerShare']:
    if data2['Offset_symbol'].iloc[j] == data2['symbol'].iloc[j]:
        data2['PY_revenuePerShare'].iloc[j] = data2['revenuePerShare'].iloc[j+1]
        data2['PY_netIncomePerShare'].iloc[j] = data2['netIncomePerShare'].iloc[j+1]
        data2['PY_operatingCashFlowPerShare'].iloc[j] = data2['operatingCashFlowPerShare'].iloc[j+1]
        data2['PY_marketCap'].iloc[j] = data2['marketCap'].iloc[j+1]
        data2['PY_peRatio'].iloc[j] = data2['peRatio'].iloc[j+1]
        data2['PY_interestCoverage'].iloc[j] = data2['interestCoverage'].iloc[j+1]
        data2['PY_dividendYield'].iloc[j] = data2['dividendYield'].iloc[j+1]

    else:
        data2['PY_revenuePerShare'].iloc[j] = "NA"
        data2['PY_netIncomePerShare'].iloc[j] = "NA"
        data2['PY_operatingCashFlowPerShare'].iloc[j] = "NA"
        data2['PY_marketCap'].iloc[j] = "NA"
        data2['PY_peRatio'].iloc[j] = "NA"
        data2['PY_interestCoverage'].iloc[j] = "NA"
        data2['PY_dividendYield'].iloc[j] = "NA"
        
    j = j+1

data2
# Out:
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\211383028.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['PY_revenuePerShare'].iloc[j] = data2['revenuePerShare'].iloc[j+1]
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\211383028.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['PY_netIncomePerShare'].iloc[j] = data2['netIncomePerShare'].iloc[j+1]
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\211383028.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['PY_operatingCashFlowPerShare'].iloc[j] = data2['operatingCashFlowPerShare'].iloc[j+1]
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\211383028.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['PY_marketCap'].iloc[j] = data2['marketCap'].iloc[j+1]
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\211383028.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['PY_peRatio'].iloc[j] = data2['peRatio'].iloc[j+1]
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\211383028.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['PY_interestCoverage'].iloc[j] = data2['interestCoverage'].iloc[j+1]
# C:\Users\willm\AppData\Local\Temp\ipykernel_10212\211383028.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['PY_dividendYield'].iloc[j] = data2['dividendYield'].iloc[j+1]
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 30008      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 30009      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 30010      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 30011      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 30012      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period  ...    peRatio  \
# 0              ZYXI  ZYXI-2022  0.551722     FY  ...  31.995663
# 1              ZYXI  ZYXI-2021 -0.259287     FY  ...  16.556313
# 2              ZYXI  ZYXI-2020  0.710293     FY  ...  67.446863
# 3              ZYXI  ZYXI-2019  1.676871     FY  ...  33.252370
# 4              ZYXI  ZYXI-2018 -0.050388     FY  ...  13.100560
# ...             ...        ...       ...    ...  ...        ...
# 30008             A     A-2020  0.397909     FY  ...  50.239361
# 30009             A     A-2019  0.275396     FY  ...  24.283790
# 30010             A     A-2018  0.016654     FY  ...  74.639555
# 30011             A     A-2017  0.483179     FY  ...  33.708946
# 30012             0     A-2016       inf     FY  ...  31.699870
#
#        interestCoverage  dividendYield  PY_revenuePerShare  \
# 0             52.131818       0.006624            3.400606
# 1            235.431579       0.000004            2.150586
# 2            539.421053            NaN            1.274336
# 3           2213.200000       0.007167            0.892701
# 4             67.337662            NaN            0.662452
# ...                 ...            ...                 ...
# 30008         10.846154       0.006146           16.034161
# 30009         12.716216       0.007921            15.07362
# 30010         12.373333       0.008098           13.429429
# 30011         10.645570       0.007373           12.618619
# 30012          8.541667       0.010242                  NA
#
#        PY_netIncomePerShare  PY_operatingCashFlowPerShare   PY_marketCap  \
# 0                  0.446355                      0.181356    283162618.8
# 1                  0.243559                      0.021956    612012832.7
# 2                   0.26601                      0.176639    315631493.4
# 3                  0.267164                      0.263137    125136550.0
# 4                  0.208218                      0.233521    154991906.5
# ...                     ...                           ...            ...
# 30008              3.326087                      3.170807  26007938905.0
# 30009              0.969325                      3.334356  23586099511.0
# 30010              2.054054                       2.66967  23056919301.0
# 30011              1.387387                      2.381381  14645339834.0
# 30012                    NA                            NA             NA
#
#       PY_peRatio PY_interestCoverage PY_dividendYield
# 0      16.556313          235.431579         0.000004
# 1      67.446863          539.421053              NaN
# 2       33.25237              2213.2         0.007167
# 3       13.10056           67.337662              NaN
# 4      21.044386            6.168276              NaN
# ...          ...                 ...              ...
# 30008   24.28379           12.716216         0.007921
# 30009  74.639555           12.373333         0.008098
# 30010  33.708946            10.64557         0.007373
# 30011   31.69987            8.541667         0.010242
# 30012         NA                  NA               NA
#
# [30013 rows x 24 columns]

# %%
# Export clean prices to csv
data2.to_csv('Data2.csv')

# %%
# Check for duplicates
# Check symbols with value counts equal to 1 (only 1 year of data)
print('Count of symbols = 1:', (data2['Key'].value_counts() == 1).sum())
print('Count of symbols > 1:', (data2['Key'].value_counts() > 1).sum())
# Out:
# Count of symbols = 1: 29673
# Count of symbols > 1: 170

# %%
# Remove duplicates where Key values counts >1
data3 = data2.copy()
data3 = data3[data3.groupby('Key').Key.transform('count')==1]
data3
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 30008      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 30009      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 30010      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 30011      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 30012      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period  ...    peRatio  \
# 0              ZYXI  ZYXI-2022  0.551722     FY  ...  31.995663
# 1              ZYXI  ZYXI-2021 -0.259287     FY  ...  16.556313
# 2              ZYXI  ZYXI-2020  0.710293     FY  ...  67.446863
# 3              ZYXI  ZYXI-2019  1.676871     FY  ...  33.252370
# 4              ZYXI  ZYXI-2018 -0.050388     FY  ...  13.100560
# ...             ...        ...       ...    ...  ...        ...
# 30008             A     A-2020  0.397909     FY  ...  50.239361
# 30009             A     A-2019  0.275396     FY  ...  24.283790
# 30010             A     A-2018  0.016654     FY  ...  74.639555
# 30011             A     A-2017  0.483179     FY  ...  33.708946
# 30012             0     A-2016       inf     FY  ...  31.699870
#
#        interestCoverage  dividendYield  PY_revenuePerShare  \
# 0             52.131818       0.006624            3.400606
# 1            235.431579       0.000004            2.150586
# 2            539.421053            NaN            1.274336
# 3           2213.200000       0.007167            0.892701
# 4             67.337662            NaN            0.662452
# ...                 ...            ...                 ...
# 30008         10.846154       0.006146           16.034161
# 30009         12.716216       0.007921            15.07362
# 30010         12.373333       0.008098           13.429429
# 30011         10.645570       0.007373           12.618619
# 30012          8.541667       0.010242                  NA
#
#        PY_netIncomePerShare  PY_operatingCashFlowPerShare   PY_marketCap  \
# 0                  0.446355                      0.181356    283162618.8
# 1                  0.243559                      0.021956    612012832.7
# 2                   0.26601                      0.176639    315631493.4
# 3                  0.267164                      0.263137    125136550.0
# 4                  0.208218                      0.233521    154991906.5
# ...                     ...                           ...            ...
# 30008              3.326087                      3.170807  26007938905.0
# 30009              0.969325                      3.334356  23586099511.0
# 30010              2.054054                       2.66967  23056919301.0
# 30011              1.387387                      2.381381  14645339834.0
# 30012                    NA                            NA             NA
#
#       PY_peRatio PY_interestCoverage PY_dividendYield
# 0      16.556313          235.431579         0.000004
# 1      67.446863          539.421053              NaN
# 2       33.25237              2213.2         0.007167
# 3       13.10056           67.337662              NaN
# 4      21.044386            6.168276              NaN
# ...          ...                 ...              ...
# 30008   24.28379           12.716216         0.007921
# 30009  74.639555           12.373333         0.008098
# 30010  33.708946            10.64557         0.007373
# 30011   31.69987            8.541667         0.010242
# 30012         NA                  NA               NA
#
# [29673 rows x 24 columns]

# %%
# Check for duplicates
# Check symbols with value counts equal to 1 (only 1 year of data)
print('Count of symbols = 1:', (data3['Key'].value_counts() == 1).sum())
print('Count of symbols > 1:', (data3['Key'].value_counts() > 1).sum())
# Out:
# Count of symbols = 1: 29673
# Count of symbols > 1: 0

# %%
# Drop unnecessary columns:
data4 = data3.copy()
data4 = data3.drop(['revenuePerShare','netIncomePerShare','operatingCashFlowPerShare','marketCap', 'peRatio',
             'interestCoverage', 'dividendYield'], axis=1)
data4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 30008      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 30009      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 30010      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 30011      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 30012      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period PY_revenuePerShare  \
# 0              ZYXI  ZYXI-2022  0.551722     FY           3.400606
# 1              ZYXI  ZYXI-2021 -0.259287     FY           2.150586
# 2              ZYXI  ZYXI-2020  0.710293     FY           1.274336
# 3              ZYXI  ZYXI-2019  1.676871     FY           0.892701
# 4              ZYXI  ZYXI-2018 -0.050388     FY           0.662452
# ...             ...        ...       ...    ...                ...
# 30008             A     A-2020  0.397909     FY          16.034161
# 30009             A     A-2019  0.275396     FY           15.07362
# 30010             A     A-2018  0.016654     FY          13.429429
# 30011             A     A-2017  0.483179     FY          12.618619
# 30012             0     A-2016       inf     FY                 NA
#
#       PY_netIncomePerShare PY_operatingCashFlowPerShare   PY_marketCap  \
# 0                 0.446355                     0.181356    283162618.8
# 1                 0.243559                     0.021956    612012832.7
# 2                  0.26601                     0.176639    315631493.4
# 3                 0.267164                     0.263137    125136550.0
# 4                 0.208218                     0.233521    154991906.5
# ...                    ...                          ...            ...
# 30008             3.326087                     3.170807  26007938905.0
# 30009             0.969325                     3.334356  23586099511.0
# 30010             2.054054                      2.66967  23056919301.0
# 30011             1.387387                     2.381381  14645339834.0
# 30012                   NA                           NA             NA
#
#       PY_peRatio PY_interestCoverage PY_dividendYield
# 0      16.556313          235.431579         0.000004
# 1      67.446863          539.421053              NaN
# 2       33.25237              2213.2         0.007167
# 3       13.10056           67.337662              NaN
# 4      21.044386            6.168276              NaN
# ...          ...                 ...              ...
# 30008   24.28379           12.716216         0.007921
# 30009  74.639555           12.373333         0.008098
# 30010  33.708946            10.64557         0.007373
# 30011   31.69987            8.541667         0.010242
# 30012         NA                  NA               NA
#
# [29673 rows x 17 columns]

# %%
profile = ("https://financialmodelingprep.com/api/v3/profile/AAPL?apikey=4f3f56682d5bbab7a42251bad1821ade")

# %%
tickers_list
# Out:
# ['ZYXI',
#  'ZYME',
#  'ZXZZT',
#  'ZXYZ-A',
#  'ZWS',
#  'ZVIA',
#  'ZUO',
#  'ZUMZ',
#  'ZTST',
#  'ZTS',
#  'ZTO',
#  'ZTEK',
#  'ZS',
#  'ZNTL',
#  'ZM',
#  'ZLAB',
#  'ZKIN',
#  'ZJZZT',
#  'ZIVOW',
#  'ZIVO',
#  'ZIP',
#  'ZIONP',
#  'ZIONO',
#  'ZIONL',
#  'ZION',
#  'ZIM',
#  'ZI',
#  'ZH',
#  'ZGN',
#  'ZG',
#  'ZFOXW',
#  'ZFOX',
#  'ZEV',
#  'ZEUS',
#  'ZETA',
#  'ZEPP',
#  'ZENV',
#  'ZD',
#  'ZCMD',
#  'ZBRA',
#  'ZBH',
#  'Z',
#  'YY',
#  'YUMC',
#  'YUM',
#  'YTRA',
#  'YTEN',
#  'YSG',
#  'YS',
#  'YRD',
#  'YQ',
#  'YPF',
#  'YOU',
#  'YORW',
#  'YMM',
#  'YMAB',
#  'YJ',
#  'YI',
#  'YGMZ',
#  'YEXT',
#  'YETI',
#  'YELP',
#  'YALA',
#  'XYL',
#  'XYF',
#  'XXII',
#  'XWEL',
#  'XTLB',
#  'XRX',
#  'XRTX',
#  'XRAY',
#  'XPRO',
#  'XPOF',
#  'XPO',
#  'XPEV',
#  'XPER',
#  'XPEL',
#  'XPDBU',
#  'XP',
#  'XOSWW',
#  'XOS',
#  'XOMAP',
#  'XOMAO',
#  'XOMA',
#  'XOM',
#  'XNET',
#  'XNCR',
#  'XMTR',
#  'XLO',
#  'XIN',
#  'XHR',
#  'XGN',
#  'XFOR',
#  'XFINW',
#  'XFINU',
#  'XFIN',
#  'XERS',
#  'XENE',
#  'XELB',
#  'XELA',
#  'XEL',
#  'XCUR',
#  'XBIT',
#  'XBIO',
#  'XAIR',
#  'X',
#  'WYNN',
#  'WY',
#  'WWW',
#  'WWD',
#  'WW',
#  'WVVIP',
#  'WVVI',
#  'WVE',
#  'WULF',
#  'WU',
#  'WTW',
#  'WTTR',
#  'WTS',
#  'WTRG',
#  'WTM',
#  'WTI',
#  'WTFCP',
#  'WTFCM',
#  'WTFC',
#  'WTER',
#  'WTBA',
#  'WT',
#  'WST',
#  'WSO',
#  'WSM',
#  'WSFS',
#  'WSC',
#  'WSBF',
#  'WSBCP',
#  'WSBC',
#  'WRLD',
#  'WRK',
#  'WRBY',
#  'WRB',
#  'WRAP',
#  'WPRT',
#  'WPP',
#  'WPM',
#  'WPC',
#  'WOW',
#  'WORX',
#  'WOR',
#  'WOOF',
#  'WOLF',
#  'WNW',
#  'WNS',
#  'WNEB',
#  'WNC',
#  'WMT',
#  'WMS',
#  'WMPN',
#  'WMK',
#  'WMG',
#  'WMB',
#  'WM',
#  'WLYB',
#  'WLY',
#  'WLKP',
#  'WLK',
#  'WLFC',
#  'WLDN',
#  'WKSPW',
#  'WKSP',
#  'WKME',
#  'WKHS',
#  'WKEY',
#  'WK',
#  'WIX',
#  'WIT',
#  'WISH',
#  'WISA',
#  'WIRE',
#  'WINVW',
#  'WINVU',
#  'WINV',
#  'WINT',
#  'WING',
#  'WINA',
#  'WIMI',
#  'WILC',
#  'WHR',
#  'WHLRP',
#  'WHLRD',
#  'WHLR',
#  'WHLM',
#  'WHG',
#  'WHF',
#  'WHD',
#  'WH',
#  'WGS',
#  'WGO',
#  'WFRD',
#  'WFG',
#  'WFCF',
#  'WFC-PZ',
#  'WFC-PY',
#  'WFC-PR',
#  'WFC-PL',
#  'WFC-PD',
#  'WFC-PC',
#  'WFC-PA',
#  'WFC',
#  'WF',
#  'WEYS',
#  'WEX',
#  'WETG',
#  'WEST',
#  'WES',
#  'WERN',
#  'WEN',
#  'WELL',
#  'WEC',
#  'WEAV',
#  'WDS',
#  'WDH',
#  'WDFC',
#  'WDC',
#  'WDAY',
#  'WD',
#  'WCN',
#  'WCC-PA',
#  'WCC',
#  'WBX',
#  'WBS-PF',
#  'WBS',
#  'WBD',
#  'WBA',
#  'WB',
#  'WAVE',
#  'WAVD',
#  'WATT',
#  'WAT',
#  'WALDW',
#  'WALD',
#  'WAL-PA',
#  'WAL',
#  'WAFU',
#  'WAFDP',
#  'WAFD',
#  'WABC',
#  'WAB',
#  'W',
#  'VZIO',
#  'VZ',
#  'VYNT',
#  'VYNE',
#  'VYGR',
#  'VXRT',
#  'VWEWW',
#  'VWE',
#  'VVX',
#  'VVV',
#  'VVPR',
#  'VVOS',
#  'VVI',
#  'VUZI',
#  'VTYX',
#  'VTVT',
#  'VTSI',
#  'VTRU',
#  'VTRS',
#  'VTR',
#  'VTOL',
#  'VTNR',
#  'VTGN',
#  'VTEX',
#  'VSTO',
#  'VSTM',
#  'VSTA',
#  'VST',
#  'VSSYW',
#  'VSH',
#  'VSEC',
#  'VSCO',
#  'VSAT',
#  'VSACW',
#  'VSAC',
#  'VS',
#  'VRTX',
#  'VRTS',
#  'VRT',
#  'VRSN',
#  'VRSK',
#  'VRRM',
#  'VRPX',
#  'VRNT',
#  'VRNS',
#  'VRNA',
#  'VRMEW',
#  'VRME',
#  'VRM',
#  'VREX',
#  'VRE',
#  'VRDN',
#  'VRCA',
#  'VRAR',
#  'VRA',
#  'VPG',
#  'VOYA-PB',
#  'VOYA',
#  'VOXX',
#  'VOXR',
#  'VOR',
#  'VOD',
#  'VNT',
#  'VNOM',
#  'VNET',
#  'VNDA',
#  'VNCE',
#  'VMI',
#  'VMEO',
#  'VMD',
#  'VMC',
#  'VMAR',
#  'VLYPP',
#  'VLYPO',
#  'VLY',
#  'VLRS',
#  'VLO',
#  'VLN',
#  'VLGEA',
#  'VLD',
#  'VLCN',
#  'VKTX',
#  'VJET',
#  'VIVK',
#  'VIVE',
#  'VIV',
#  'VITL',
#  'VIST',
#  'VISL',
#  'VIRX',
#  'VIRT',
#  'VIRI',
#  'VIRC',
#  'VIR',
#  'VIPS',
#  'VIOT',
#  'VINP',
#  'VINO',
#  'VINC',
#  'VIIAW',
#  'VIIAU',
#  'VII',
#  'VIEWW',
#  'VIEW',
#  'VICR',
#  'VICI',
#  'VIAV',
#  'VIASP',
#  'VIAO',
#  'VIA',
#  'VHI',
#  'VHC',
#  'VGR',
#  'VGAS',
#  'VFF',
#  'VFC',
#  'VEV',
#  'VET',
#  'VERY',
#  'VERX',
#  'VERV',
#  'VERU',
#  'VERO',
#  'VERI',
#  'VERBW',
#  'VERB',
#  'VERA',
#  'VEON',
#  'VEL',
#  'VEEV',
#  'VEEE',
#  'VECO',
#  'VCYT',
#  'VCTR',
#  'VCSA',
#  'VCNX',
#  'VCEL',
#  'VC',
#  'VBTX',
#  'VBNK',
#  'VBIV',
#  'VAXX',
#  'VATE',
#  'VAQC',
#  'VAPO',
#  'VANI',
#  'VALU',
#  'VALN',
#  'VALE',
#  'VAL',
#  'VAC',
#  'VABK',
#  'V',
#  'UZF',
#  'UZE',
#  'UZD',
#  'UXIN',
#  'UWMC',
#  'UVV',
#  'UVSP',
#  'UVE',
#  'UTZ',
#  'UTSI',
#  'UTRS',
#  'UTMD',
#  'UTL',
#  'UTI',
#  'UTHR',
#  'UTF',
#  'USPH',
#  'USNA',
#  'USM',
#  'USLM',
#  'USIO',
#  'USFD',
#  'USEG',
#  'USDP',
#  'USCTW',
#  'USCT',
#  'USCB',
#  'USB-PR',
#  'USB-PQ',
#  'USB-PP',
#  'USB-PH',
#  'USB-PA',
#  'USB',
#  'USAU',
#  'USAP',
#  'USAC',
#  'UROY',
#  'URI',
#  'URGN',
#  'URBN',
#  'UPXI',
#  'UPWK',
#  'UPST',
#  'UPS',
#  'UPLD',
#  'UPH',
#  'UPC',
#  'UP',
#  'UONEK',
#  'UONE',
#  'UNTY',
#  'UNP',
#  'UNMA',
#  'UNM',
#  'UNIT',
#  'UNH',
#  'UNFI',
#  'UNF',
#  'UNCY',
#  'UNB',
#  'UMH-PD',
#  'UMH',
#  'UMC',
#  'UMBF',
#  'ULTA',
#  'ULH',
#  'ULCC',
#  'ULBI',
#  'UL',
#  'UKOMW',
#  'UK',
#  'UIS',
#  'UI',
#  'UHS',
#  'UHAL',
#  'UGRO',
#  'UGP',
#  'UGIC',
#  'UGI',
#  'UG',
#  'UFPT',
#  'UFPI',
#  'UFI',
#  'UFCS',
#  'UEIC',
#  'UE',
#  'UDR',
#  'UDMY',
#  'UCTT',
#  'UCL',
#  'UCBIO',
#  'UCBI',
#  'UBX',
#  'UBSI',
#  'UBS',
#  'UBOH',
#  'UBFO',
#  'UBER',
#  'UBCP',
#  'UAN',
#  'UAL',
#  'UAA',
#  'UA',
#  'U',
#  'TZOO',
#  'TYRA',
#  'TYL',
#  'TYG',
#  'TY-P',
#  'TY',
#  'TXT',
#  'TXRH',
#  'TXN',
#  'TXMD',
#  'TXG',
#  'TX',
#  'TWST',
#  'TWOU',
#  'TWOA',
#  'TWO-PC',
#  'TWO-PB',
#  'TWO-PA',
#  'TWO',
#  'TWN',
#  'TWLVW',
#  'TWLV',
#  'TWLO',
#  'TWKS',
#  'TWIN',
#  'TWI',
#  'TW',
#  'TVTX',
#  'TVE',
#  'TVC',
#  'TV',
#  'TUYA',
#  'TUSK',
#  'TURN',
#  'TUP',
#  'TU',
#  'TTWO',
#  'TTSH',
#  'TTP',
#  'TTOO',
#  'TTNP',
#  'TTMI',
#  'TTI',
#  'TTGT',
#  'TTEK',
#  'TTEC',
#  'TTE',
#  'TTD',
#  'TTC',
#  'TT',
#  'TSVT',
#  'TSRI',
#  'TSQ',
#  'TSP',
#  'TSN',
#  'TSM',
#  'TSLX',
#  'TSLA',
#  'TSI',
#  'TSHA',
#  'TSEM',
#  'TSE',
#  'TSCO',
#  'TSBK',
#  'TSAT',
#  'TS',
#  'TRVN',
#  'TRVI',
#  'TRVG',
#  'TRV',
#  'TRUP',
#  'TRUE',
#  'TRU',
#  'TRTX-PC',
#  'TRTX',
#  'TRTN-PE',
#  'TRTN-PD',
#  'TRTN-PC',
#  'TRTN-PB',
#  'TRTN-PA',
#  'TRTL',
#  'TRST',
#  'TRS',
#  'TRP',
#  'TROX',
#  'TROW',
#  'TROO',
#  'TRONW',
#  'TRON',
#  'TRNS',
#  'TRNO',
#  'TRN',
#  'TRMR',
#  'TRMK',
#  'TRMD',
#  'TRMB',
#  'TRKAW',
#  'TRKA',
#  'TRIS-UN',
#  'TRIS',
#  'TRIP',
#  'TRIN',
#  'TRIB',
#  'TRI',
#  'TRGP',
#  'TREX',
#  'TREE',
#  'TRDA',
#  'TRCA',
#  'TRC',
#  'TR',
#  'TPZ',
#  'TPX',
#  'TPVG',
#  'TPTA',
#  'TPST',
#  'TPR',
#  'TPL',
#  'TPIC',
#  'TPH',
#  'TPC',
#  'TPB',
#  'TOWN',
#  'TOVX',
#  'TOUR',
#  'TOST',
#  'TOPS',
#  'TOMZ',
#  'TOL',
#  'TOIIW',
#  'TOI',
#  'TNYA',
#  'TNXP',
#  'TNP-PF',
#  'TNP-PE',
#  'TNP',
#  'TNL',
#  'TNK',
#  'TNGX',
#  'TNET',
#  'TNDM',
#  'TNC',
#  'TMUS',
#  'TMST',
#  'TMPOW',
#  'TMPO',
#  'TMO',
#  'TMHC',
#  'TME',
#  'TMDX',
#  'TMCWW',
#  'TMCI',
#  'TMC',
#  'TM',
#  'TLYS',
#  'TLSA',
#  'TLS',
#  'TLRY',
#  'TLK',
#  'TLIS',
#  'TLGYU',
#  'TLF',
#  'TKR',
#  'TKNO',
#  'TKC',
#  'TK',
#  'TJX',
#  'TIXT',
#  'TIVC',
#  'TITN',
#  'TISI',
#  'TIRX',
#  'TIPT',
#  'TIMB',
#  'TILE',
#  'TIL',
#  'TIGR',
#  'TIGO',
#  'THWWW',
#  'THTX',
#  'THS',
#  'THRY',
#  'THRX',
#  'THRM',
#  'THR',
#  'THO',
#  'THMO',
#  'THG',
#  'THFF',
#  'THCPW',
#  'THCPU',
#  'THCP',
#  'THCH',
#  'THC',
#  'TH',
#  'TGVCW',
#  'TGVC',
#  'TGTX',
#  'TGT',
#  'TGS',
#  'TGNA',
#  'TGLS',
#  'TGI',
#  'TGH-PB',
#  'TGH-PA',
#  'TGH',
#  'TGAN',
#  'TGAAU',
#  'TG',
#  'TFX',
#  'TFSL',
#  'TFPM',
#  'TFINP',
#  'TFIN',
#  'TFII',
#  'TFFP',
#  'TFC-PR',
#  'TFC-PO',
#  'TFC-PI',
#  'TFC',
#  'TEX',
#  'TEVA',
#  'TERN',
#  'TER',
#  'TEO',
#  'TENX',
#  'TENB',
#  'TELA',
#  'TEL',
#  'TEF',
#  'TEDU',
#  'TECTP',
#  'TECK',
#  'TECH',
#  'TEAM',
#  'TDY',
#  'TDW',
#  'TDUP',
#  'TDS-PV',
#  'TDS',
#  'TDOC',
#  'TDG',
#  'TDF',
#  'TDCX',
#  'TDC',
#  'TD',
#  'TCX',
#  'TCS',
#  'TCRX',
#  'TCRT',
#  'TCPC',
#  'TCON',
#  'TCOM',
#  'TCOA-UN',
#  'TCN',
#  'TCMD',
#  'TCI',
#  'TCBX',
#  'TCBS',
#  'TCBK',
#  'TCBIO',
#  'TCBI',
#  'TCBC',
#  'TC',
#  'TBPH',
#  'TBNK',
#  'TBLT',
#  'TBLAW',
#  'TBLA',
#  'TBIO',
#  'TBI',
#  'TBCPW',
#  'TBCPU',
#  'TBC',
#  'TBBK',
#  'TBB',
#  'TAYD',
#  'TATT',
#  'TAST',
#  'TASK',
#  'TARS',
#  'TARO',
#  'TARA',
#  'TAP-A',
#  'TAP',
#  'TAOP',
#  'TANH',
#  'TALO',
#  'TALKW',
#  'TALK',
#  'TAL',
#  'TAK',
#  'TAIT',
#  'TACT',
#  'TAC',
#  'T-PC',
#  'T-PA',
#  'T',
#  'SZZL',
#  'SYY',
#  'SYTAW',
#  'SYTA',
#  'SYRS',
#  'SYPR',
#  'SYNA',
#  'SYM',
#  'SYK',
#  'SYF-PA',
#  'SYF',
#  'SYBX',
#  'SYBT',
#  'SY',
#  'SXTC',
#  'SXT',
#  'SXI',
#  'SXC',
#  'SWX',
#  'SWVL',
#  'SWTX',
#  'SWN',
#  'SWKS',
#  'SWKH',
#  'SWK',
#  'SWIM',
#  'SWI',
#  'SWBI',
#  'SWAV',
#  'SWAGW',
#  'SWAG',
#  'SVVC',
#  'SVRA',
#  'SVFD',
#  'SUZ',
#  'SURGW',
#  'SURG',
#  'SUPV',
#  'SUPN',
#  'SUP',
#  'SUNW',
#  'SUN',
#  'SUM',
#  'SUI',
#  'SU',
#  'STZ',
#  'STX',
#  'STWD',
#  'STVN',
#  'STTK',
#  'STT-PG',
#  'STT-PD',
#  'STT',
#  'STRT',
#  'STRS',
#  'STRRP',
#  'STRR',
#  'STRO',
#  'STRM',
#  'STRL',
#  'STRCW',
#  'STRC',
#  'STRA',
#  'STR',
#  'STOK',
#  'STNG',
#  'STNE',
#  'STN',
#  'STM',
#  'STLD',
#  'STLA',
#  'STKS',
#  'STKL',
#  'STKH',
#  'STIX',
#  'STIM',
#  'STGW',
#  'STG',
#  'STEW',
#  'STER',
#  'STEP',
#  'STEM',
#  'STEL',
#  'STE',
#  'STCN',
#  'STC',
#  'STBA',
#  'STAG',
#  'STAF',
#  'STAB',
#  'STAA',
#  'ST',
#  'SSYS',
#  'SSTK',
#  'SSTI',
#  'SST',
#  'SSSSL',
#  'SSSS',
#  'SSRM',
#  'SSP',
#  'SSNT',
#  'SSNC',
#  'SSL',
#  'SSKN',
#  'SSD',
#  'SSBK',
#  'SSBI',
#  'SSB',
#  'SRZNW',
#  'SRZN',
#  'SRTS',
#  'SRT',
#  'SRRK',
#  'SRPT',
#  'SRL',
#  'SRI',
#  'SRG-PA',
#  'SRG',
#  'SREA',
#  'SRE',
#  'SRDX',
#  'SRCL',
#  'SRCE',
#  'SRC-PA',
#  'SRC',
#  'SRAX',
#  'SRAD',
#  'SR-PA',
#  'SR',
#  'SQSP',
#  'SQNS',
#  'SQM',
#  'SQFTP',
#  'SQFT',
#  'SQ',
#  'SPXC',
#  'SPWR',
#  'SPWH',
#  'SPTN',
#  'SPT',
#  'SPSC',
#  'SPRY',
#  'SPRU',
#  'SPRO',
#  'SPRC',
#  'SPRB',
#  'SPR',
#  'SPOT',
#  'SPOK',
#  'SPNT-PB',
#  'SPNT',
#  'SPNS',
#  'SPLP-PA',
#  'SPLP',
#  'SPLK',
#  'SPIR',
#  'SPI',
#  'SPH',
#  'SPGI',
#  'SPG-PJ',
#  'SPG',
#  'SPFI',
#  'SPE',
#  'SPCE',
#  'SPCB',
#  'SPB',
#  'SP',
#  'SOVO',
#  'SOUNW',
#  'SOTK',
#  'SOS',
#  'SOR',
#  'SOPH',
#  'SOPA',
#  'SONY',
#  'SONX',
#  'SONO',
#  'SONN',
#  'SONM',
#  'SONDW',
#  'SOND',
#  'SON',
#  'SOLO',
#  'SOL',
#  'SOJE',
#  'SOJD',
#  'SOJC',
#  'SOI',
#  'SOHU',
#  'SOHOO',
#  'SOHON',
#  'SOHOB',
#  'SOHO',
#  'SOFO',
#  'SOFI',
#  'SOBR',
#  'SO',
#  ...]

# %% [markdown]
# ## Pull sector data for each stock ticker
# - Note: subscription may be required
# - Alternative method: Manually upload sector information from csv file(s):

# %%
## Get company profile / sector data from stocks on tickers_list ##

base_profile = ("https://financialmodelingprep.com/api/v3/profile/")
end_profile = ("?apikey=4f3f56682d5bbab7a42251bad1821ade")     

json_list_profile = []
for i in tickers_list:
    url_profile = base_profile + i + end_profile
    #print(get_jsonparsed_data(url))
    #print(url)
    json_profile = pd.read_json(url_profile)
    json_list_profile.append(json_profile)
   

json_list_profile

# %%
# Convert pricing JSON files into dataframe 
df_profile = pd.concat(json_list_profile, axis=0, ignore_index=True)
# Out:
#      symbol     price      beta   volAvg       mktCap  lastDiv          range  \
# 0      REGN  828.7250  0.209400   650534  89093738575     0.00  538.01-837.55
# 1      AMOT   34.9150  1.481234    65657    561475098     0.10    21.14-44.88
# 2      RELX   32.6250  0.480077   817552  62139205728     0.65   23.39-32.885
# 3      AMRN    1.3500  1.881795  4835590    548256600     0.00      1.04-3.74
# 4       RES    7.8750  1.819010  1394749   1712812500     0.16      5.7-12.91
# ...     ...       ...       ...      ...          ...      ...            ...
# 6853   BNNR   10.2400  0.000000    76055    200959990     0.00    9.795-10.39
# 6854  BNNRU   10.2400  0.000000     4622    194610340     0.00    8.93-10.415
# 6855  BNNRW    0.0400  0.000000        0            0     0.00      0.04-0.04
# 6856  BOCNU   10.2800  0.000000     2691    242204417     0.00      9.9-10.28
# 6857   BODY    0.4902  1.511002   462114    157833597     0.00      0.42-2.33
#
#       changes                      companyName currency  ...         zip  \
# 0      6.6349  Regeneron Pharmaceuticals, Inc.      USD  ...  10591-6707
# 1     -1.3850  Allied Motion Technologies Inc.      USD  ...       14228
# 2      0.0150                         RELX PLC      USD  ...    WC2N 5JR
# 3     -0.0800           Amarin Corporation plc      USD  ...           2
# 4     -0.1150                        RPC, Inc.      USD  ...       30329
# ...       ...                              ...      ...  ...         ...
# 6853   0.0100         Banner Acquisition Corp.      USD  ...       84043
# 6854   0.0000         Banner Acquisition Corp.      USD  ...       84043
# 6855   0.0000         Banner Acquisition Corp.      NaN  ...         NaN
# 6856   0.0400     Blue Ocean Acquisition Corp.      USD  ...       20815
# 6857  -0.0398      The Beachbody Company, Inc.      USD  ...       90245
#
#         dcfDiff        dcf                                              image  \
# 0     21.220400  764.05000  https://financialmodelingprep.com/image-stock/...
# 1      1.672720   37.40730  https://financialmodelingprep.com/image-stock/...
# 2      1.781340   27.62870  https://financialmodelingprep.com/image-stock/...
# 3      0.125150    1.72485  https://financialmodelingprep.com/image-stock/...
# 4      0.332271    9.78227  https://financialmodelingprep.com/image-stock/...
# ...         ...        ...                                                ...
# 6853        NaN    0.00000  https://financialmodelingprep.com/image-stock/...
# 6854        NaN    0.00000  https://financialmodelingprep.com/image-stock/...
# 6855        NaN    0.00000  https://financialmodelingprep.com/image-stock/...
# 6856        NaN    0.00000  https://financialmodelingprep.com/image-stock/...
# 6857        NaN    0.00000  https://financialmodelingprep.com/image-stock/...
#
#          ipoDate defaultImage  isEtf isActivelyTrading  isAdr isFund
# 0     1991-01-01        False  False              True  False  False
# 1     1980-10-20        False  False              True  False  False
# 2     1994-10-06        False  False              True   True  False
# 3     1993-04-01        False  False              True   True  False
# 4     1984-07-02        False  False              True  False  False
# ...          ...          ...    ...               ...    ...    ...
# 6853  2021-10-29        False  False              True  False  False
# 6854  2021-09-08        False  False              True  False  False
# 6855                     True  False              True  False  False
# 6856                    False  False              True  False  False
# 6857  2021-01-15        False  False              True  False  False
#
# [6858 rows x 36 columns]

# %%
df_profile['sector'].value_counts()
# Out:
# Financial Services        1723
# Healthcare                1257
# Technology                 788
# Industrials                707
# Consumer Cyclical          574
#                            375
# Real Estate                354
# Communication Services     282
# Consumer Defensive         237
# Energy                     230
# Basic Materials            206
# Utilities                  125
# Name: sector, dtype: int64

# %%
# Get dataframe with symbol and sector only
    
df_sector = df_profile[['symbol', 'sector']]
df_sector
# Out:
#      symbol                  sector
# 0      REGN              Healthcare
# 1      AMOT              Technology
# 2      RELX  Communication Services
# 3      AMRN              Healthcare
# 4       RES                  Energy
# ...     ...                     ...
# 6853   BNNR      Financial Services
# 6854  BNNRU      Financial Services
# 6855  BNNRW
# 6856  BOCNU      Financial Services
# 6857   BODY  Communication Services
#
# [6858 rows x 2 columns]

# %%
df_sector['sector'] == ''
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6853    False
# 6854    False
# 6855     True
# 6856    False
# 6857    False
# Name: sector, Length: 6858, dtype: bool

# %%
df_sector['sector'].iloc[6855] == ''
# Out:
# True

# %%
df_sector2 = df_sector.copy()

j = 0
for i in df_sector2['sector']:
    if df_sector2['sector'].iloc[j] == '':
        df_sector2['sector'].iloc[j] = 'NA'
    else:
        print(j)
    j = j+1

df_sector2

# %%
# Export to CSV
df_sector2.to_csv('Sector.csv')

# %% [markdown]
# ## Alternate method: upload sector data from csv file

# %%
df_sector3 = pd.read_csv('Data/Sector.csv')
df_sector3
# Out:
#       Unnamed: 0 symbol                  sector
# 0              0   REGN              Healthcare
# 1              1   AMOT              Technology
# 2              2   RELX  Communication Services
# 3              3   AMRN              Healthcare
# 4              4    RES                  Energy
# ...          ...    ...                     ...
# 6853        6853   BNNR      Financial Services
# 6854        6854  BNNRU      Financial Services
# 6855        6855  BNNRW                     NaN
# 6856        6856  BOCNU      Financial Services
# 6857        6857   BODY  Communication Services
#
# [6858 rows x 3 columns]

# %%
# Join sector data with pricing & financial ratio data:
stock_data = pd.merge(data4, df_sector3, how='inner', on = 'symbol')
stock_data
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 29613      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 29614      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 29615      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 29616      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 29617      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period PY_revenuePerShare  \
# 0              ZYXI  ZYXI-2022  0.551722     FY           3.400606
# 1              ZYXI  ZYXI-2021 -0.259287     FY           2.150586
# 2              ZYXI  ZYXI-2020  0.710293     FY           1.274336
# 3              ZYXI  ZYXI-2019  1.676871     FY           0.892701
# 4              ZYXI  ZYXI-2018 -0.050388     FY           0.662452
# ...             ...        ...       ...    ...                ...
# 29613             A     A-2020  0.397909     FY          16.034161
# 29614             A     A-2019  0.275396     FY           15.07362
# 29615             A     A-2018  0.016654     FY          13.429429
# 29616             A     A-2017  0.483179     FY          12.618619
# 29617             0     A-2016       inf     FY                 NA
#
#       PY_netIncomePerShare PY_operatingCashFlowPerShare   PY_marketCap  \
# 0                 0.446355                     0.181356    283162618.8
# 1                 0.243559                     0.021956    612012832.7
# 2                  0.26601                     0.176639    315631493.4
# 3                 0.267164                     0.263137    125136550.0
# 4                 0.208218                     0.233521    154991906.5
# ...                    ...                          ...            ...
# 29613             3.326087                     3.170807  26007938905.0
# 29614             0.969325                     3.334356  23586099511.0
# 29615             2.054054                      2.66967  23056919301.0
# 29616             1.387387                     2.381381  14645339834.0
# 29617                   NA                           NA             NA
#
#       PY_peRatio PY_interestCoverage PY_dividendYield  Unnamed: 0      sector
# 0      16.556313          235.431579         0.000004         637  Healthcare
# 1      67.446863          539.421053              NaN         637  Healthcare
# 2       33.25237              2213.2         0.007167         637  Healthcare
# 3       13.10056           67.337662              NaN         637  Healthcare
# 4      21.044386            6.168276              NaN         637  Healthcare
# ...          ...                 ...              ...         ...         ...
# 29613   24.28379           12.716216         0.007921        2520  Healthcare
# 29614  74.639555           12.373333         0.008098        2520  Healthcare
# 29615  33.708946            10.64557         0.007373        2520  Healthcare
# 29616   31.69987            8.541667         0.010242        2520  Healthcare
# 29617         NA                  NA               NA        2520  Healthcare
#
# [29618 rows x 19 columns]

# %%
# S&P 500 returns manually sourced from Yahoo Finance:
    ## https://finance.yahoo.com/quote/SPY/performance?p=SPY
    # 2016 = 12.00%
    # 2017 = 21.70%
    # 2018 = -4.56%
    # 2019 = 31.22%
    # 2020 = 18.37%
    # 2021 = 28.75%
    # 2022 = -18.17%

SP_data = [[2016, 0.1200], [2017, 0.2170], [2018, -0.0456], [2019, 0.3122], [2020, 0.1837], [2021, 0.2875], [2022, -0.1817]]
df_SP = pd.DataFrame(SP_data, columns=['Year', 'S&P500_return'])
df_SP
# Out:
#    Year  S&P500_return
# 0  2016         0.1200
# 1  2017         0.2170
# 2  2018        -0.0456
# 3  2019         0.3122
# 4  2020         0.1837
# 5  2021         0.2875
# 6  2022        -0.1817

# %%
# Pull S&P500 returns into stock dataframe:
stock_data2 = pd.merge(left = stock_data, right = df_SP, how='left', on = 'Year')
stock_data2
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 29613      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 29614      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 29615      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 29616      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 29617      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#       Offset_symbol        Key    Return period PY_revenuePerShare  \
# 0              ZYXI  ZYXI-2022  0.551722     FY           3.400606
# 1              ZYXI  ZYXI-2021 -0.259287     FY           2.150586
# 2              ZYXI  ZYXI-2020  0.710293     FY           1.274336
# 3              ZYXI  ZYXI-2019  1.676871     FY           0.892701
# 4              ZYXI  ZYXI-2018 -0.050388     FY           0.662452
# ...             ...        ...       ...    ...                ...
# 29613             A     A-2020  0.397909     FY          16.034161
# 29614             A     A-2019  0.275396     FY           15.07362
# 29615             A     A-2018  0.016654     FY          13.429429
# 29616             A     A-2017  0.483179     FY          12.618619
# 29617             0     A-2016       inf     FY                 NA
#
#       PY_netIncomePerShare PY_operatingCashFlowPerShare   PY_marketCap  \
# 0                 0.446355                     0.181356    283162618.8
# 1                 0.243559                     0.021956    612012832.7
# 2                  0.26601                     0.176639    315631493.4
# 3                 0.267164                     0.263137    125136550.0
# 4                 0.208218                     0.233521    154991906.5
# ...                    ...                          ...            ...
# 29613             3.326087                     3.170807  26007938905.0
# 29614             0.969325                     3.334356  23586099511.0
# 29615             2.054054                      2.66967  23056919301.0
# 29616             1.387387                     2.381381  14645339834.0
# 29617                   NA                           NA             NA
#
#       PY_peRatio PY_interestCoverage PY_dividendYield  Unnamed: 0      sector  \
# 0      16.556313          235.431579         0.000004         637  Healthcare
# 1      67.446863          539.421053              NaN         637  Healthcare
# 2       33.25237              2213.2         0.007167         637  Healthcare
# 3       13.10056           67.337662              NaN         637  Healthcare
# 4      21.044386            6.168276              NaN         637  Healthcare
# ...          ...                 ...              ...         ...         ...
# 29613   24.28379           12.716216         0.007921        2520  Healthcare
# 29614  74.639555           12.373333         0.008098        2520  Healthcare
# 29615  33.708946            10.64557         0.007373        2520  Healthcare
# 29616   31.69987            8.541667         0.010242        2520  Healthcare
# 29617         NA                  NA               NA        2520  Healthcare
#
#        S&P500_return
# 0            -0.1817
# 1             0.2875
# 2             0.1837
# 3             0.3122
# 4            -0.0456
# ...              ...
# 29613         0.1837
# 29614         0.3122
# 29615        -0.0456
# 29616         0.2170
# 29617         0.1200
#
# [29618 rows x 20 columns]

# %%
# Drop unnecessary columns:
stock_data3 = stock_data2.copy()
stock_data3 = stock_data3.drop(columns=['Offset_symbol'])
stock_data3
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 29613      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 29614      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 29615      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 29616      A  12/29/2017   66.970000   64.488472  2017    43.479897
# 29617      A  12/30/2016   45.560000   43.479897  2016     0.000000
#
#              Key    Return period PY_revenuePerShare PY_netIncomePerShare  \
# 0      ZYXI-2022  0.551722     FY           3.400606             0.446355
# 1      ZYXI-2021 -0.259287     FY           2.150586             0.243559
# 2      ZYXI-2020  0.710293     FY           1.274336              0.26601
# 3      ZYXI-2019  1.676871     FY           0.892701             0.267164
# 4      ZYXI-2018 -0.050388     FY           0.662452             0.208218
# ...          ...       ...    ...                ...                  ...
# 29613     A-2020  0.397909     FY          16.034161             3.326087
# 29614     A-2019  0.275396     FY           15.07362             0.969325
# 29615     A-2018  0.016654     FY          13.429429             2.054054
# 29616     A-2017  0.483179     FY          12.618619             1.387387
# 29617     A-2016       inf     FY                 NA                   NA
#
#       PY_operatingCashFlowPerShare   PY_marketCap PY_peRatio  \
# 0                         0.181356    283162618.8  16.556313
# 1                         0.021956    612012832.7  67.446863
# 2                         0.176639    315631493.4   33.25237
# 3                         0.263137    125136550.0   13.10056
# 4                         0.233521    154991906.5  21.044386
# ...                            ...            ...        ...
# 29613                     3.170807  26007938905.0   24.28379
# 29614                     3.334356  23586099511.0  74.639555
# 29615                      2.66967  23056919301.0  33.708946
# 29616                     2.381381  14645339834.0   31.69987
# 29617                           NA             NA         NA
#
#       PY_interestCoverage PY_dividendYield  Unnamed: 0      sector  \
# 0              235.431579         0.000004         637  Healthcare
# 1              539.421053              NaN         637  Healthcare
# 2                  2213.2         0.007167         637  Healthcare
# 3               67.337662              NaN         637  Healthcare
# 4                6.168276              NaN         637  Healthcare
# ...                   ...              ...         ...         ...
# 29613           12.716216         0.007921        2520  Healthcare
# 29614           12.373333         0.008098        2520  Healthcare
# 29615            10.64557         0.007373        2520  Healthcare
# 29616            8.541667         0.010242        2520  Healthcare
# 29617                  NA               NA        2520  Healthcare
#
#        S&P500_return
# 0            -0.1817
# 1             0.2875
# 2             0.1837
# 3             0.3122
# 4            -0.0456
# ...              ...
# 29613         0.1837
# 29614         0.3122
# 29615        -0.0456
# 29616         0.2170
# 29617         0.1200
#
# [29618 rows x 19 columns]

# %%
# Drop NA rows:
stock_data4 = stock_data3.copy()
stock_data4.drop(stock_data4.loc[stock_data4['PY_revenuePerShare'] == 'NA'].index, inplace=True)
stock_data4.drop(stock_data4.loc[stock_data4['Return'] == 'inf'].index, inplace=True)
stock_data4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 29612      A  12/31/2021  159.650000  158.397827  2021   116.890472
# 29613      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 29614      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 29615      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 29616      A  12/29/2017   66.970000   64.488472  2017    43.479897
#
#              Key    Return period PY_revenuePerShare PY_netIncomePerShare  \
# 0      ZYXI-2022  0.551722     FY           3.400606             0.446355
# 1      ZYXI-2021 -0.259287     FY           2.150586             0.243559
# 2      ZYXI-2020  0.710293     FY           1.274336              0.26601
# 3      ZYXI-2019  1.676871     FY           0.892701             0.267164
# 4      ZYXI-2018 -0.050388     FY           0.662452             0.208218
# ...          ...       ...    ...                ...                  ...
# 29612     A-2021  0.355096     FY          17.278317             2.326861
# 29613     A-2020  0.397909     FY          16.034161             3.326087
# 29614     A-2019  0.275396     FY           15.07362             0.969325
# 29615     A-2018  0.016654     FY          13.429429             2.054054
# 29616     A-2017  0.483179     FY          12.618619             1.387387
#
#       PY_operatingCashFlowPerShare   PY_marketCap PY_peRatio  \
# 0                         0.181356    283162618.8  16.556313
# 1                         0.021956    612012832.7  67.446863
# 2                         0.176639    315631493.4   33.25237
# 3                         0.263137    125136550.0   13.10056
# 4                         0.233521    154991906.5  21.044386
# ...                            ...            ...        ...
# 29612                     2.980583  36122100464.0  50.239361
# 29613                     3.170807  26007938905.0   24.28379
# 29614                     3.334356  23586099511.0  74.639555
# 29615                      2.66967  23056919301.0  33.708946
# 29616                     2.381381  14645339834.0   31.69987
#
#       PY_interestCoverage PY_dividendYield  Unnamed: 0      sector  \
# 0              235.431579         0.000004         637  Healthcare
# 1              539.421053              NaN         637  Healthcare
# 2                  2213.2         0.007167         637  Healthcare
# 3               67.337662              NaN         637  Healthcare
# 4                6.168276              NaN         637  Healthcare
# ...                   ...              ...         ...         ...
# 29612           10.846154         0.006146        2520  Healthcare
# 29613           12.716216         0.007921        2520  Healthcare
# 29614           12.373333         0.008098        2520  Healthcare
# 29615            10.64557         0.007373        2520  Healthcare
# 29616            8.541667         0.010242        2520  Healthcare
#
#        S&P500_return
# 0            -0.1817
# 1             0.2875
# 2             0.1837
# 3             0.3122
# 4            -0.0456
# ...              ...
# 29612         0.2875
# 29613         0.1837
# 29614         0.3122
# 29615        -0.0456
# 29616         0.2170
#
# [24003 rows x 19 columns]

# %%
# Convert financial columns to float data types
stock_data4 = stock_data4.astype({'PY_revenuePerShare' : 'float', 'PY_netIncomePerShare' :'float', 'PY_operatingCashFlowPerShare' : 'float',
                                'PY_marketCap' : 'float', 'PY_peRatio' : 'float', 'PY_interestCoverage' : 'float', 
                                  'PY_dividendYield' : 'float'})
stock_data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24003 entries, 0 to 29616
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   symbol                        24003 non-null  object
#  1   date                          24003 non-null  object
#  2   close                         24003 non-null  float64
#  3   adjClose                      24003 non-null  float64
#  4   Year                          24003 non-null  int64
#  5   PY_adjClose                   24003 non-null  float64
#  6   Key                           24003 non-null  object
#  7   Return                        24003 non-null  float64
#  8   period                        24003 non-null  object
#  9   PY_revenuePerShare            23469 non-null  float64
#  10  PY_netIncomePerShare          23469 non-null  float64
#  11  PY_operatingCashFlowPerShare  23469 non-null  float64
#  12  PY_marketCap                  23469 non-null  float64
#  13  PY_peRatio                    23387 non-null  float64
#  14  PY_interestCoverage           21021 non-null  float64
#  15  PY_dividendYield              12058 non-null  float64
#  16  Unnamed: 0                    24003 non-null  int64
#  17  sector                        23791 non-null  object
#  18  S&P500_return                 24003 non-null  float64
# dtypes: float64(12), int64(2), object(5)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Apply market cap categories according to FINRA

# %%
# Apply market cap categories according to FINRA: 
    # Micro-cap < 250mm ()
    # Small cap = 250mm to 2B
    # Mid cap = 2B to 10B
    # Large cap = > 10B
# https://www.finra.org/investors/insights/market-cap#:~:text=large%2Dcap%3A%20market%20value%20between,of%20less%20than%20%24250%20million

# Create market cap conditions
conditions = [
    (stock_data4['PY_marketCap'] < 250000000),
    (stock_data4['PY_marketCap'] > 250000000) & (stock_data4['PY_marketCap'] <= 2000000000),
    (stock_data4['PY_marketCap'] > 2000000000) & (stock_data4['PY_marketCap'] <= 10000000000),
    (stock_data4['PY_marketCap'] > 10000000000)
]

# Create market cap values to assign for each condition
values = ['micro-cap', 'small-cap', 'mid-cap', 'large-cap']

# Create new column and assign values
stock_data4['MarketCap_Tier'] = np.select(conditions, values)

stock_data4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 29612      A  12/31/2021  159.650000  158.397827  2021   116.890472
# 29613      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 29614      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 29615      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 29616      A  12/29/2017   66.970000   64.488472  2017    43.479897
#
#              Key    Return period  PY_revenuePerShare  PY_netIncomePerShare  \
# 0      ZYXI-2022  0.551722     FY            3.400606              0.446355
# 1      ZYXI-2021 -0.259287     FY            2.150586              0.243559
# 2      ZYXI-2020  0.710293     FY            1.274336              0.266010
# 3      ZYXI-2019  1.676871     FY            0.892701              0.267164
# 4      ZYXI-2018 -0.050388     FY            0.662452              0.208218
# ...          ...       ...    ...                 ...                   ...
# 29612     A-2021  0.355096     FY           17.278317              2.326861
# 29613     A-2020  0.397909     FY           16.034161              3.326087
# 29614     A-2019  0.275396     FY           15.073620              0.969325
# 29615     A-2018  0.016654     FY           13.429429              2.054054
# 29616     A-2017  0.483179     FY           12.618619              1.387387
#
#        PY_operatingCashFlowPerShare  PY_marketCap  PY_peRatio  \
# 0                          0.181356  2.831626e+08   16.556313
# 1                          0.021956  6.120128e+08   67.446863
# 2                          0.176639  3.156315e+08   33.252370
# 3                          0.263137  1.251366e+08   13.100560
# 4                          0.233521  1.549919e+08   21.044386
# ...                             ...           ...         ...
# 29612                      2.980583  3.612210e+10   50.239361
# 29613                      3.170807  2.600794e+10   24.283790
# 29614                      3.334356  2.358610e+10   74.639555
# 29615                      2.669670  2.305692e+10   33.708946
# 29616                      2.381381  1.464534e+10   31.699870
#
#        PY_interestCoverage  PY_dividendYield  Unnamed: 0      sector  \
# 0               235.431579          0.000004         637  Healthcare
# 1               539.421053               NaN         637  Healthcare
# 2              2213.200000          0.007167         637  Healthcare
# 3                67.337662               NaN         637  Healthcare
# 4                 6.168276               NaN         637  Healthcare
# ...                    ...               ...         ...         ...
# 29612            10.846154          0.006146        2520  Healthcare
# 29613            12.716216          0.007921        2520  Healthcare
# 29614            12.373333          0.008098        2520  Healthcare
# 29615            10.645570          0.007373        2520  Healthcare
# 29616             8.541667          0.010242        2520  Healthcare
#
#        S&P500_return MarketCap_Tier
# 0            -0.1817      small-cap
# 1             0.2875      small-cap
# 2             0.1837      small-cap
# 3             0.3122      micro-cap
# 4            -0.0456      micro-cap
# ...              ...            ...
# 29612         0.2875      large-cap
# 29613         0.1837      large-cap
# 29614         0.3122      large-cap
# 29615        -0.0456      large-cap
# 29616         0.2170      large-cap
#
# [24003 rows x 20 columns]

# %% [markdown]
# ## Add binary target: "Did stock beat the S&P500 in the given year?"

# %%
# Add binary target column (as Yes/No):

conditions2 = [
    stock_data4['Return'] > stock_data4['S&P500_return'],
    stock_data4['Return'] <= stock_data4['S&P500_return']
]

values2 = ['Yes', 'No']

stock_data4['Beat_S&P?'] = np.select(conditions2, values2)

stock_data4
# Out:
#       symbol        date       close    adjClose  Year  PY_adjClose  \
# 0       ZYXI  12/30/2022   13.910000   13.910000  2022     8.964234
# 1       ZYXI  12/31/2021    9.063600    8.964234  2021    12.102167
# 2       ZYXI  12/31/2020   12.236400   12.102167  2020     7.076080
# 3       ZYXI  12/31/2019    7.154500    7.076080  2019     2.643415
# 4       ZYXI  12/31/2018    2.644294    2.643415  2018     2.783678
# ...      ...         ...         ...         ...   ...          ...
# 29612      A  12/31/2021  159.650000  158.397827  2021   116.890472
# 29613      A  12/31/2020  118.490000  116.890472  2020    83.618065
# 29614      A  12/31/2019   85.310000   83.618065  2019    65.562431
# 29615      A  12/31/2018   67.460000   65.562431  2018    64.488472
# 29616      A  12/29/2017   66.970000   64.488472  2017    43.479897
#
#              Key    Return period  PY_revenuePerShare  ...  \
# 0      ZYXI-2022  0.551722     FY            3.400606  ...
# 1      ZYXI-2021 -0.259287     FY            2.150586  ...
# 2      ZYXI-2020  0.710293     FY            1.274336  ...
# 3      ZYXI-2019  1.676871     FY            0.892701  ...
# 4      ZYXI-2018 -0.050388     FY            0.662452  ...
# ...          ...       ...    ...                 ...  ...
# 29612     A-2021  0.355096     FY           17.278317  ...
# 29613     A-2020  0.397909     FY           16.034161  ...
# 29614     A-2019  0.275396     FY           15.073620  ...
# 29615     A-2018  0.016654     FY           13.429429  ...
# 29616     A-2017  0.483179     FY           12.618619  ...
#
#        PY_operatingCashFlowPerShare  PY_marketCap  PY_peRatio  \
# 0                          0.181356  2.831626e+08   16.556313
# 1                          0.021956  6.120128e+08   67.446863
# 2                          0.176639  3.156315e+08   33.252370
# 3                          0.263137  1.251366e+08   13.100560
# 4                          0.233521  1.549919e+08   21.044386
# ...                             ...           ...         ...
# 29612                      2.980583  3.612210e+10   50.239361
# 29613                      3.170807  2.600794e+10   24.283790
# 29614                      3.334356  2.358610e+10   74.639555
# 29615                      2.669670  2.305692e+10   33.708946
# 29616                      2.381381  1.464534e+10   31.699870
#
#        PY_interestCoverage  PY_dividendYield  Unnamed: 0      sector  \
# 0               235.431579          0.000004         637  Healthcare
# 1               539.421053               NaN         637  Healthcare
# 2              2213.200000          0.007167         637  Healthcare
# 3                67.337662               NaN         637  Healthcare
# 4                 6.168276               NaN         637  Healthcare
# ...                    ...               ...         ...         ...
# 29612            10.846154          0.006146        2520  Healthcare
# 29613            12.716216          0.007921        2520  Healthcare
# 29614            12.373333          0.008098        2520  Healthcare
# 29615            10.645570          0.007373        2520  Healthcare
# 29616             8.541667          0.010242        2520  Healthcare
#
#       S&P500_return  MarketCap_Tier Beat_S&P?
# 0           -0.1817       small-cap       Yes
# 1            0.2875       small-cap        No
# 2            0.1837       small-cap       Yes
# 3            0.3122       micro-cap       Yes
# 4           -0.0456       micro-cap        No
# ...             ...             ...       ...
# 29612        0.2875       large-cap       Yes
# 29613        0.1837       large-cap       Yes
# 29614        0.3122       large-cap        No
# 29615       -0.0456       large-cap       Yes
# 29616        0.2170       large-cap       Yes
#
# [24003 rows x 21 columns]

# %%
   ## re-order columns
clean_df = stock_data4.copy()
clean_df = clean_df.loc[:,['Key', 'symbol', 'period', 'Year', 'Return', 'S&P500_return', 'Beat_S&P?', 'sector', 'MarketCap_Tier',
                           'PY_revenuePerShare','PY_netIncomePerShare', 'PY_operatingCashFlowPerShare', 'PY_marketCap', 'PY_peRatio',
                               	'PY_interestCoverage', 'PY_dividendYield' ,'close', 'adjClose', 'PY_adjClose', 'date']]

clean_df
# Out:
#              Key symbol period  Year    Return  S&P500_return Beat_S&P?  \
# 0      ZYXI-2022   ZYXI     FY  2022  0.551722        -0.1817       Yes
# 1      ZYXI-2021   ZYXI     FY  2021 -0.259287         0.2875        No
# 2      ZYXI-2020   ZYXI     FY  2020  0.710293         0.1837       Yes
# 3      ZYXI-2019   ZYXI     FY  2019  1.676871         0.3122       Yes
# 4      ZYXI-2018   ZYXI     FY  2018 -0.050388        -0.0456        No
# ...          ...    ...    ...   ...       ...            ...       ...
# 29612     A-2021      A     FY  2021  0.355096         0.2875       Yes
# 29613     A-2020      A     FY  2020  0.397909         0.1837       Yes
# 29614     A-2019      A     FY  2019  0.275396         0.3122        No
# 29615     A-2018      A     FY  2018  0.016654        -0.0456       Yes
# 29616     A-2017      A     FY  2017  0.483179         0.2170       Yes
#
#            sector MarketCap_Tier  PY_revenuePerShare  PY_netIncomePerShare  \
# 0      Healthcare      small-cap            3.400606              0.446355
# 1      Healthcare      small-cap            2.150586              0.243559
# 2      Healthcare      small-cap            1.274336              0.266010
# 3      Healthcare      micro-cap            0.892701              0.267164
# 4      Healthcare      micro-cap            0.662452              0.208218
# ...           ...            ...                 ...                   ...
# 29612  Healthcare      large-cap           17.278317              2.326861
# 29613  Healthcare      large-cap           16.034161              3.326087
# 29614  Healthcare      large-cap           15.073620              0.969325
# 29615  Healthcare      large-cap           13.429429              2.054054
# 29616  Healthcare      large-cap           12.618619              1.387387
#
#        PY_operatingCashFlowPerShare  PY_marketCap  PY_peRatio  \
# 0                          0.181356  2.831626e+08   16.556313
# 1                          0.021956  6.120128e+08   67.446863
# 2                          0.176639  3.156315e+08   33.252370
# 3                          0.263137  1.251366e+08   13.100560
# 4                          0.233521  1.549919e+08   21.044386
# ...                             ...           ...         ...
# 29612                      2.980583  3.612210e+10   50.239361
# 29613                      3.170807  2.600794e+10   24.283790
# 29614                      3.334356  2.358610e+10   74.639555
# 29615                      2.669670  2.305692e+10   33.708946
# 29616                      2.381381  1.464534e+10   31.699870
#
#        PY_interestCoverage  PY_dividendYield       close    adjClose  \
# 0               235.431579          0.000004   13.910000   13.910000
# 1               539.421053               NaN    9.063600    8.964234
# 2              2213.200000          0.007167   12.236400   12.102167
# 3                67.337662               NaN    7.154500    7.076080
# 4                 6.168276               NaN    2.644294    2.643415
# ...                    ...               ...         ...         ...
# 29612            10.846154          0.006146  159.650000  158.397827
# 29613            12.716216          0.007921  118.490000  116.890472
# 29614            12.373333          0.008098   85.310000   83.618065
# 29615            10.645570          0.007373   67.460000   65.562431
# 29616             8.541667          0.010242   66.970000   64.488472
#
#        PY_adjClose        date
# 0         8.964234  12/30/2022
# 1        12.102167  12/31/2021
# 2         7.076080  12/31/2020
# 3         2.643415  12/31/2019
# 4         2.783678  12/31/2018
# ...            ...         ...
# 29612   116.890472  12/31/2021
# 29613    83.618065  12/31/2020
# 29614    65.562431  12/31/2019
# 29615    64.488472  12/31/2018
# 29616    43.479897  12/29/2017
#
# [24003 rows x 20 columns]

# %%
# Save the dataframe to CSV file
clean_df.to_csv('Stock_List_v2.csv')
print("Stock listed exported to working directory")
# Out:
# Stock listed exported to working directory
